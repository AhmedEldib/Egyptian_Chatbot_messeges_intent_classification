# %% [markdown]
# # IMPORTS

# %%
# Out:
# /bin/bash: transformers-cli: command not found

# %%
# !pip install transformers
# Out:
# Collecting transformers
#   Downloading https://files.pythonhosted.org/packages/d5/43/cfe4ee779bbd6a678ac6a97c5a5cdeb03c35f9eaebbb9720b036680f9a2d/transformers-4.6.1-py3-none-any.whl (2.2MB)
#      |████████████████████████████████| 2.3MB 31.5MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.0.12)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers) (20.9)
# Collecting huggingface-hub==0.0.8
#   Downloading https://files.pythonhosted.org/packages/a1/88/7b1e45720ecf59c6c6737ff332f41c955963090a18e72acbcbeac6b25e86/huggingface_hub-0.0.8-py3-none-any.whl
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading https://files.pythonhosted.org/packages/d4/e2/df3543e8ffdab68f5acc73f613de9c2b155ac47f162e725dcac87c521c11/tokenizers-0.10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3MB)
#      |████████████████████████████████| 3.3MB 47.6MB/s
# Collecting sacremoses
#   Downloading https://files.pythonhosted.org/packages/75/ee/67241dc87f266093c533a2d4d3d69438e57d7a90abb216fa076e7d475d4a/sacremoses-0.0.45-py3-none-any.whl (895kB)
#      |████████████████████████████████| 901kB 47.7MB/s
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from transformers) (4.0.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.41.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.19.5)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers) (2.4.7)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.0.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers) (3.4.1)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers) (3.7.4.3)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2020.12.5)
# Installing collected packages: huggingface-hub, tokenizers, sacremoses, transformers
# Successfully installed huggingface-hub-0.0.8 sacremoses-0.0.45 tokenizers-0.10.3 transformers-4.6.1

# %%
# !transformers-cli login
# Out:
# 2021-06-03 16:19:17.344044: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
#
#         _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#         _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#         _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#         _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#         _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#
# Username: MoaazZaki
# Password:
# Login successful
# Your token: OEqtkNwiXTsyXBcunOOSaEGLcvnIjkIxacSmiMADDfrdNAPcMeQokvypgzUbwiZQWrhCuaQyHPkEqkglbwjGPyqpePosUGDgfkCPPktBGKXxfTCDBnkEfkcREhEnZigG
#
# Your token has been saved to /root/.huggingface/token

# %%
# !pip install sentencepiece
# Out:
# Collecting sentencepiece
#   Downloading https://files.pythonhosted.org/packages/f5/99/e0808cb947ba10f575839c43e8fafc9cc44e4a7a2c8f79c60db48220a577/sentencepiece-0.1.95-cp37-cp37m-manylinux2014_x86_64.whl (1.2MB)
#      |████████████████████████████████| 1.2MB 31.4MB/s
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.1.95

# %%
# !pip install demoji
import demoji
demoji.download_codes()
# Out:
# Collecting demoji
#   Downloading https://files.pythonhosted.org/packages/88/6a/34379abe01c9c36fe9fddc4181dd935332e7d0159ec3fae76f712e49bcea/demoji-0.4.0-py2.py3-none-any.whl
# Requirement already satisfied: requests<3.0.0 in /usr/local/lib/python3.7/dist-packages (from demoji) (2.23.0)
# Collecting colorama
#   Downloading https://files.pythonhosted.org/packages/44/98/5b86278fbbf250d239ae0ecb724f8572af1c91f4a11edf4d36a206189440/colorama-0.4.4-py2.py3-none-any.whl
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0->demoji) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0->demoji) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0->demoji) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0->demoji) (3.0.4)
# Installing collected packages: colorama, demoji
# Successfully installed colorama-0.4.4 demoji-0.4.0
# Downloading emoji data ...
# ... OK (Got response in 0.13 seconds)
# Writing emoji data to /root/.demoji/codes.json ...
# ... OK

# %%
# !pip install pyarabic
# Out:
# Collecting pyarabic
#   Downloading https://files.pythonhosted.org/packages/7b/e2/46728ec2f6fe14970de5c782346609f0636262c0941228f363710903aaa1/PyArabic-0.6.10.tar.gz (108kB)
#      |████████████████████████████████| 112kB 25.4MB/s
# Building wheels for collected packages: pyarabic
#   Building wheel for pyarabic (setup.py) ... done
#   Created wheel for pyarabic: filename=PyArabic-0.6.10-cp37-none-any.whl size=113324 sha256=49ed272115297577ff8bf1228f223233a9e2c62e1debeca22ebb751cc720ccde
#   Stored in directory: /root/.cache/pip/wheels/10/b8/f5/b7c1a50e6efb83544844f165a9b134afe7292585465e29b61d
# Successfully built pyarabic
# Installing collected packages: pyarabic
# Successfully installed pyarabic-0.6.10

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Assesting libraries
import numpy as np
import pandas as pd
import re

#from pyarabic import araby
from keras.preprocessing.sequence import pad_sequences
from snowballstemmer import stemmer
from nltk import wordpunct_tokenize
from nltk.stem.isri import ISRIStemmer

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# from tensorflow import keras
# from tensorflow.keras import layers

# from tensorflow.keras.layers import Embedding, Dense, Input, Dropout, Bidirectional, BatchNormalization, Flatten, Reshape
# from keras.layers.convolutional import Conv1D,MaxPooling1D
# from keras.layers.merge import concatenate
# from keras.models import Model
# from keras.preprocessing.text import Tokenizer, text_to_word_sequence
# from sklearn.model_selection import train_test_split
# import tensorflow as tf

# %% [markdown]
# # Dataset Importing

# %%
! apt install 2to3
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   2to3
# 0 upgraded, 1 newly installed, 0 to remove and 39 not upgraded.
# Need to get 8,044 B of archives.
# After this operation, 43.0 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 2to3 all 3.6.7-1~18.04 [8,044 B]
# Fetched 8,044 B in 0s (51.2 kB/s)
# Selecting previously unselected package 2to3.
# (Reading database ... 160772 files and directories currently installed.)
# Preparing to unpack .../2to3_3.6.7-1~18.04_all.deb ...
# Unpacking 2to3 (3.6.7-1~18.04) ...
# Setting up 2to3 (3.6.7-1~18.04) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...

# %%
#Constants
TOKENIZER_WORD_NUM = 50000
#Files
DATA_TRAIN_PATH = '/content/drive/MyDrive/dataset/train_ara.csv'
#DATA_LABELS_PATH = '/content/drive/MyDrive/dataset/labels.txt'
#Values
MAX_VOCAB_SIZE = 50000
EMBEDDING_DIM = 300
DELTA = 1e-12
BETA = 1e-6
GAMMA = 1e-3

# %%
data = pd.read_csv(DATA_TRAIN_PATH)
data
# Out:
#                                                   text                      intent
# 0          كم عدد مستشفيات العزل فى مصر وما هى اماكنها           business location
# 1                                              ومخاصمك          nothing identified
# 2                                    متي ينتهي كورونا؟  the evolution of the virus
# 3                                              انا اسف          nothing identified
# 4                             كام عدد الوفيات النهارده              infected cases
# ..                                                 ...                         ...
# 786                                               اهلا                    greeting
# 787                                                بلح          nothing identified
# 788                                     كم عدد الحالات              infected cases
# 789                             متى ينتهى فيروس كورونا  the evolution of the virus
# 790  ممكن اعرف متى يتم الانتهاء من فيرس كرونا وهل ي...                warm weather
#
# [791 rows x 2 columns]

# %% [markdown]
# # Data Fixing

# %%
mask = ['قناع','ماسك','كمامة','كمامه','للوجه','وجه','الوجه','واقي']
extended_mask = [] 
for i,val in enumerate(mask):
  if i > 3:
    extended_mask += [val] * 2
  else:
    extended_mask += [val] *4
label_mask = ['muzzle/mask'] * len(extended_mask)
print(len(extended_mask) == len(label_mask))
# Out:
# True

# %%
temper = ['درجة','درجات','درجه','حرارة','حراره','الحرارة','الحراره']
extended_temper = []
for i,val in enumerate(temper):
  extended_temper += [val] * 3
label_temper = ['warm weather'] * len(extended_temper)
print(len(label_temper) == len(extended_temper))
# Out:
# True

# %%
treatment = ['سخن','درجة','درجه','حرارة','حراره','الحرارة','الحراره','حرارتي','صداع','سخونية','سخونيه','الم','الام','بكح','كح','برد','عطس']
label_treatment = ['treatment'] * len(treatment)
treatment
print(len(treatment) == len(label_treatment))
# Out:
# True

# %%
lab = ['تحليل','حلل','مسحة','مسحه','فحص','pcr']
extended_lab = []
for i,val in enumerate(lab):
  extended_lab += [val] * 4
label_lab = ['laboratory'] * len(extended_lab)
print(len(label_lab) == len(extended_lab))
# Out:
# True

# %%
evolution = ['ينتهى','ينتهي','انتهاء','متوقع','المتوقع'] 
extended_evolution = []
for i,val in enumerate(evolution):
  extended_evolution += [val] * 2
label_evolution = ['the evolution of the virus'] * len(extended_evolution)
print(len(label_evolution) == len(extended_evolution))
# Out:
# True

# %%
yes = ['نعم','اكيد','بالتأكيد','👍','اه'] 
extended_yes = []
for i,val in enumerate(yes):
  extended_yes += [val] * 6
label_yes = ['yes'] * len(extended_yes)
extended_yes
print(len(label_yes) == len(extended_yes))
# Out:
# True

# %%
no = ['خلاص','لا'] 
extended_no = []
for i,val in enumerate(no):
  extended_no += [val] * 6
label_no = ['no'] * len(extended_no)
extended_no
print(len(label_no) == len(extended_no))
# Out:
# True

# %%
end = ['باي','سلام','مع السلامة','مع السلامه'] 
extended_end = []
for i,val in enumerate(end):
  extended_end += [val] * 10
label_end = ['end conversation'] * len(extended_end)
print(len(label_end) == len(extended_end))
# Out:
# True

# %%
len(augmented_labels)
# Out:
# 178

# %%
augmented_labels = label_mask + label_temper + label_treatment + label_lab + label_evolution + label_yes + label_no +label_end
augmented_text = extended_mask +  extended_temper + treatment  + extended_lab + extended_evolution + extended_yes + extended_no +extended_end
augmented_data = pd.DataFrame()
augmented_data['text'] = augmented_text
augmented_data['intent'] = augmented_labels
augmented_data
# Out:
#            text            intent
# 0          قناع       muzzle/mask
# 1          قناع       muzzle/mask
# 2          قناع       muzzle/mask
# 3          قناع       muzzle/mask
# 4          ماسك       muzzle/mask
# ..          ...               ...
# 173  مع السلامه  end conversation
# 174  مع السلامه  end conversation
# 175  مع السلامه  end conversation
# 176  مع السلامه  end conversation
# 177  مع السلامه  end conversation
#
# [178 rows x 2 columns]

# %%
data = pd.concat([data,augmented_data],ignore_index=False)
data
# Out:
#      Unnamed: 0  ...                      intent
# 0           0.0  ...           business location
# 1           1.0  ...          nothing identified
# 2           2.0  ...  the evolution of the virus
# 3           3.0  ...          nothing identified
# 4           4.0  ...              infected cases
# ..          ...  ...                         ...
# 173         NaN  ...            end conversation
# 174         NaN  ...            end conversation
# 175         NaN  ...            end conversation
# 176         NaN  ...            end conversation
# 177         NaN  ...            end conversation
#
# [2258 rows x 3 columns]

# %% [markdown]
# # Data Analysis

# %%
np.unique(data['intent'])
# Out:
# array(['about bot', 'about business', 'about corona virus', 'assessment',
#        'back to work', 'breathing test', 'business location',
#        'comparison', 'crush', 'curfew', 'disease detection',
#        'education and work', 'emergency', 'end conversation',
#        'food and drinks', 'gloves', 'greeting', 'home quarantine',
#        'how are you', 'infected cases', 'infection by animals',
#        'kindness', 'laboratory', 'most vulnerable', 'muzzle/mask', 'no',
#        'nothing identified', 'panic among the people', 'prayers',
#        'precautions', 'reviews', 'smoking', 'spoken languages',
#        'sterilization and disinfection', 'symptoms',
#        'the evolution of the virus', 'transfer methods', 'treatment',
#        'warm weather', 'yes'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
labels = le.fit_transform(data['intent'])

# %%
prevoius_results = pd.read_csv('/content/drive/MyDrive/dataset/model.csv')
prevoius_results['labels'] = le.transform(prevoius_results['intent']) # 174 correct and 24 wrong

# %%
last_results = pd.read_csv('/content/drive/MyDrive/dataset/model8.csv')
last_results['labels'] = le.transform(last_results['intent']) # 174 correct and 24 wrong

# %%
data['intent'].value_counts()
# Out:
# infected cases                    295
# symptoms                           58
# nothing identified                 56
# reviews                            42
# greeting                           36
# precautions                        35
# treatment                          33
# assessment                         29
# transfer methods                   22
# about corona virus                 21
# the evolution of the virus         21
# sterilization and disinfection     19
# how are you                        14
# business location                  11
# home quarantine                     8
# comparison                          7
# about bot                           6
# warm weather                        6
# muzzle/mask                         6
# kindness                            6
# laboratory                          5
# spoken languages                    5
# food and drinks                     5
# panic among the people              5
# about business                      4
# most vulnerable                     4
# curfew                              3
# emergency                           3
# crush                               3
# yes                                 3
# smoking                             2
# education and work                  2
# back to work                        2
# end conversation                    2
# disease detection                   2
# no                                  2
# breathing test                      2
# gloves                              2
# prayers                             2
# infection by animals                2
# Name: intent, dtype: int64

# %%
for i in data[data['intent'] == 'the evolution of the virus'].values:
  print(i[0])

# %%
plt.figure(figsize=(15,9))
sns.countplot(labels)
plt.title('Labels counts after augmentation')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Labels counts after augmentation')

# %%
plt.figure(figsize=(15,9))
sns.countplot(data=prevoius_results, x="labels")

# %%
plt.figure(figsize=(15,9))
sns.countplot(data=last_results, x="labels")

# %%
test_data['intent'] = prevoius_results['intent']

# %%
for i in test_data.values:
  print(i)
# Out:
# ['كان إعداد الإصابات ف مصر' 'infected cases']
# ['اعداد المصابين الان في مصر بفيرس كورونا' 'infected cases']
# ['اسرائيل' 'infected cases']
# ['هل تم التوصل لمصل للوقاية من كرونا' 'treatment']
# ['الحالات في امريكا' 'infected cases']
# ['عدد الحالات في محافظة المنيا في جمهورية مصر العربية كان النهاردة'
#  'infected cases']
# ['دى اجابه خطأ' 'nothing identified']
# ['إعداد المصابين فى مصر اليوم' 'infected cases']
# ['متا تنتهي كرونا' 'the evolution of the virus']
# ['عايز أعرف كم واحد مصاب في مصر وفي الصين' 'infected cases']
# ['كم عدد الحالات في مصر والاردن' 'infected cases']
# ['وقطر' 'infected cases']
# ['لو حد بيكح من غير سخونية  يعمل ايه' 'nothing identified']
# ['اهلا نميسه' 'greeting']
# ['كان فين مستشفيات العزل في مصر' 'business location']
# ['فى مصر' 'infected cases']
# ['اعداد المصابين امس' 'infected cases']
# ['تطور العلاج' 'treatment']
# ['عدد الحالات في هولندا' 'infected cases']
# ['كم عدد الاصابات في مصر اليوم' 'infected cases']
# ['عدد حالات الكورونا في الاردن' 'infected cases']
# ['الحالات في مصر والسعوديه وصلت لكام' 'infected cases']
# ['هنا على اسم مصر وصلت بكام' 'infected cases']
# ['لا .. اريد ان اعرف عدد الحالات المصابة امس' 'infected cases']
# ['ما هي اعداد الحالات في فرنسا ؟' 'infected cases']
# ['عدد المتوفين في نيويورك بكرونا ؟؟' 'infected cases']
# ['كام عدد الوفيات اليوم' 'infected cases']
# ['ليه نسب الوفيات فى مصر عالية' 'infected cases']
# ['اولا اشكركم على هذه المعلومات القيمه' 'reviews']
# ['ماهى الادويه المطبقة للعلاج' 'treatment']
# ['بالتوفيق يا معلم' 'reviews']
# ['كيف نعالج الكرونا' 'precautions']
# ['عدد  المصابين فى كل محافظة اى ؟' 'infected cases']
# ['الإجراءات الوقائية' 'precautions']
# ['كم عدد الوفيات' 'infected cases']
# ['التطهير  في البيت ازاي' 'sterilization and disinfection']
# ['ما هي أعراض قول' 'symptoms']
# ['علي جدممتك' 'reviews']
# ['أهلا ومرحبا' 'greeting']
# ['عند انتقال شخص كبير ف السن من مكان لمكان آخر ايه الإجراءات اللازمة لحمايته؟؟؟'
#  'precautions']
# ['ايه الاخبار' 'how are you']
# ['مساء الخير' 'greeting']
# ['طرق انتقال المرض' 'transfer methods']
# ['هنرجع الشغل امتي' 'back to work']
# ['اعداد الحالات فى مصر وايطاليا اليوم' 'infected cases']
# ['شكرا لك' 'reviews']
# ['تحليل فيروس كورونا' 'about corona virus']
# ['حاسس بكتمه' 'assessment']
# ['وما هو تقييم مصر بالنسبه للمخاطره والنجاه' 'infected cases']
# ['الحالات فى ألمانيا' 'infected cases']
# ['حظر التجول' 'nothing identified']
# ['ما هي طرق السلامة من الفيرس؟' 'precautions']
# ['ما هي مده بقاء كورونا علي الاسطح' 'transfer methods']
# ['اعداد المصابين اليوم في مصر' 'infected cases']
# ['وصلنا للذروه ولا لسه؟' 'nothing identified']
# ['كلمينى عن نفسك' 'nothing identified']
# ['عايزه اعرف الأماكن الموجود فيها الفيروس في اسكندريه' 'infected cases']
# ['ايه علامات المورض' 'symptoms']
# ['االلا' 'greeting']
# ['الكمامة مهمة؟' 'nothing identified']
# ['كيف تنتقل العدوي' 'transfer methods']
# ['كم عدد الاصابات في مسر' 'infected cases']
# ['إزاي أحمي نفسي وأقل نفسي مكرونة' 'precautions']
# ['مش المفروض انه مصري' 'nothing identified']
# ['هو اللي بيكتشفو ان عندو الفيرس بيودوه اي مستشفي ولا بيروح فين بظبط؟'
#  'business location']
# ['ما هو افضل علاج يقوي مناعتي ضد فيروس كورونا' 'treatment']
# ['كم عدد حالات كورونا فى مركز كوم حماده' 'infected cases']
# ['عدد الحالات المصابة في مصر' 'infected cases']
# ['بأذن الله' 'greeting']
# ['شكرا جزيلا' 'reviews']
# ['أهلا ازيك' 'how are you']
# ['عدد الحالات في السعودية ومصر' 'infected cases']
# ['اعراض الكورونا' 'symptoms']
# ['هو يكون في علاج الكرونة إنت' 'treatment']
# ['مفيش اى معلومة مفيده' 'nothing identified']
# ['انتي غبية؟' 'nothing identified']
# ['الحمايه من كورونا' 'precautions']
# ['ايه الاعرااض' 'symptoms']
# ['أهلا' 'greeting']
# ['ما سبب تنميل الوجه والأنف  والأذن واشعر أني احتاج للهرش فيهم'
#  'assessment']
# ['الفرق ما بين كرونة فيرسو الإنفلونزا الموسمية' 'comparison']
# ['أزيك يا نميسه' 'how are you']
# ['ممكن اعرف اماكن الحجر الصحى' 'home quarantine']
# ['ماحدش راضى يعملة' 'nothing identified']
# ['متي تنتهى كورونا' 'the evolution of the virus']
# ['الحالات فى إيران' 'infected cases']
# ['عاوز اعرف كم عدد الوفيات في العالم' 'infected cases']
# ['أهلا او ازيك😅' 'how are you']
# ['اعراض الفيرس' 'symptoms']
# ['عدد المصابين في مصر جمهورية السودان' 'infected cases']
# ['السلام عليكم يا ناميسا' 'greeting']
# ['ممكن' 'nothing identified']
# ['كل محافظة داخل مصر لوحدها؟' 'infected cases']
# ['إيه الحجر المنزلي ده' 'home quarantine']
# ['الف شكر حفظكم الله' 'reviews']
# ['تطهير الشقه' 'sterilization and disinfection']
# ['السعودية كام نسما' 'infected cases']
# ['نعم ، بالتأكيد 👍' 'reviews']
# ['المصابين امس في مصر' 'infected cases']
# ['ايه هي اعراض كورونا' 'symptoms']
# ['ماهي اضرار الكرونة' 'about corona virus']
# ['ايه هو كورونا' 'about corona virus']
# ['الاضرار الناتجه بعد الشفاء' 'nothing identified']
# ['إذا كان دي اعراض الكرونا كده مفيش فرق بينها وبين اعراض البرد' 'symptoms']
# ['هو ايه الرقم اللي اتصل عليه عشان ابلغ عن ناس عندها العدوي ؟' 'emergency']
# ['انا زعلان' 'panic among the people']
# ['اوك' 'reviews']
# ['اهلان' 'greeting']
# ['عدد المصابين في امريكا' 'infected cases']
# ['اعداد المصابين في مصر النهارده' 'infected cases']
# ['إزاي أعرف إن أنا مصاب كرونو' 'symptoms']
# ['في محافظة بورسعيد' 'infected cases']
# ['بعربي' 'spoken languages']
# ['هل درجه الحراره له تأثير على كورونا' 'warm weather']
# ['اعداد المصابين اليوم' 'infected cases']
# ['كم عدد حالات الكورونا  الجديدة اليوم في مصر' 'infected cases']
# ['بالاسكندرية' 'infected cases']
# ['اعداد الحالات في امريكا' 'infected cases']
# ['ما.هى.اعراض.كورونا' 'symptoms']
# ['ارشادات الحجرالمنزلي' 'home quarantine']
# ['اهلا وانا فخورة بيكم وبالموقع جدا وان الموقع مصري بفضل. الله' 'kindness']
# ['كان عدد الحالات في النمسا' 'infected cases']
# ['اهلًا' 'greeting']
# ['في علاج ليه في مصر ولا مفيش' 'treatment']
# ['هل الأعداد المسجلة المتزايدة اليوميه كما نري في مصرتعتبر  قمة المنحني وهي نسب معقولة بالنسبة لبلد مثل مصر من ناحية مناخها (فصل الربيع ) وجينات الوراثية لشعبها  بالرغم من بعض التجاوزات وعدم التزام البعض؟؟'
#  'infected cases']
# ['اعداد الحالات في مصر' 'infected cases']
# ['كام عدد الحالات الي في هولاندا' 'infected cases']
# ['طيب و فرنسا ؟' 'infected cases']
# ['ازيك يا نميس' 'how are you']
# ['ايه اعداد الاصابات في مصر من فيرس كرونا' 'infected cases']
# ['فيكم إصابة كرونة في مصر دلوقتي' 'infected cases']
# ['عدد اصابات كرونا اليوم ف مصر' 'infected cases']
# ['اهلا وسهلا' 'greeting']
# ['كم عدد الحالات في مصر' 'infected cases']
# ['متى سينتهى كورونا في مصر ؟' 'the evolution of the virus']
# ['متشكر  اوى  انا كل يوم هشوف الجديد  وربنا يزيل هذا  الوباء' 'kindness']
# ['كم عدد الحالات في فاس المغربية؟' 'infected cases']
# ['ما هي عدد الاصابات' 'infected cases']
# ['اهلا  أرجو الرد هل موضوع كورونا مفترض أن يمتد لامتي' 'muzzle/mask']
# ['كام حالة كورونا في العالم حاليا' 'infected cases']
# ['ايه الاكلات اللي اعملها لولادي عشان تمنع العدوي' 'precautions']
# ['أهم الاحتياطات لعدم العدوي' 'precautions']
# ['اجراءات الوقاية من فيروس كورونا' 'precautions']
# ['كم عدد الحلات فى المغرب' 'infected cases']
# ['النفس عندي تقيل وعندي انسداد في الانف' 'assessment']
# ['لو عند درجة حرارة عاليه اعمل ايه' 'warm weather']
# ['موعد نهايه الوباء' 'the evolution of the virus']
# ['اهم أعراض كورونا' 'symptoms']
# ['شكرا على مجهودكم الرائع وبالتوفيق دائما' 'reviews']
# ['انتي مكانك فين' 'nothing identified']
# ['يا ترى فى اخبار عن علاج فعال للكورونا' 'treatment']
# ['هل تحبنى' 'crush']
# ['عدد الحالات داخل مصر' 'infected cases']
# ['هو ايه العلامات المبكره للاصابه' 'symptoms']
# ['لو عايز اسافر دلوقتى اعمل ايه ؟' 'nothing identified']
# ['ممكن اخد علاج لرفع المناعه' 'treatment']
# ['عايز اعرف ماهو كرونا' 'about corona virus']
# ['الجواز' 'nothing identified']
# ['نميسه ممكن اعرف عدد الاصابات الي حصلت في مصر اليوم فقط' 'infected cases']
# ['كيف اقوم بعملية تطهير مشتروات السوبر ماركت مثل أكياس المكرونة واﻻرز وعلب الشاي والصلصة وخﻻفه من المشتروات ؟'
#  'sterilization and disinfection']
# ['ماهو متوسط عدد الحالات المصابه يوميا حول العالم' 'infected cases']
# ['منوفيه' 'infected cases']
# ['عدد الإصابات بقرية صفط تراب محافظة الغربية بكرونا' 'infected cases']
# ['ايه عدد الحالات ف النمسا' 'infected cases']
# ['ما هي القرون' 'about corona virus']
# ['الحالات اليومية' 'infected cases']
# ['عدد المصابين' 'infected cases']
# ['درجات الحراره المتوقعه الايام القادمة' 'infected cases']
# ['ماهي فحوصات معرفه انتقال العدوي' 'symptoms']
# ['إنت عايز أعرف عدد المصابين في مصر وفي الصين' 'infected cases']
# ['متي ابتدأت الكرونا في الصين' 'infected cases']
# ['انا ضايق صدري' 'assessment']
# ['اقتراحات الاسئله' 'nothing identified']
# ['هل يمكن زيارة دكتور الأسنان في وجود الكورونا.' 'treatment']
# ['ساحل العاج' 'infected cases']
# ['الأعداد  الاصابه اليوم في مصر  والإعداد  المصاب في اسيوط'
#  'infected cases']
# ['كم عدد الحالات ف الصين' 'infected cases']
# ['اى هى آخر اعراض بتظهر. على الواحد من اعراض كورونل' 'symptoms']
# ['ما هو نوع القماش المفضل لعمل ماسك للوجه'
#  'sterilization and disinfection']
# ['زامبيا' 'infected cases']
# ['إيه أساليب الوقاية من قرون' 'precautions']
# ['ما' 'nothing identified']
# ['ماهي الاعراض' 'symptoms']
# ['القعدات في السعودية النهاردة كام' 'infected cases']
# ['الفيروس بيقعد اد ايه علي الاسطح' 'transfer methods']
# ['عايز اعرف اشد الأعراض الأولية لفيروس كورنا' 'symptoms']
# ['اعداد النهاردة بس كام' 'infected cases']
# ['شكرا جزيلا \nسلام' 'reviews']
# ['مع الشكر 🌹' 'reviews']
# ['اعرف ناس عملت تحليل الكورونا في اماكن اخرى فهل دة فعلا متاح ولا التحليل في الادارة المركزة فقط'
#  'laboratory']
# ['إحصائيات اليوم' 'infected cases']
# ['يعنى ايه كحول70%' 'sterilization and disinfection']
# ['ما المواد التي تضاف في الرشاش المستخدم في التعقيم المنزلي و تركيزاتها؟'
#  'sterilization and disinfection']
# ['نميسه' 'greeting']
# ['انتي مرتبطة يا نميسة ؟' 'crush']
# ['اعداد المصابين  فى بورسعيد' 'infected cases']
# ['انا جايبه عفش من دمياط و دي منطقة وباء ممكن اعرف ازاي اعقمه من غير ضرر للقماش او الخشب؟؟\nو لو في مكان موثوق للتعقيم بالفلوس ممكن تدلوني عليه؟'
#  'sterilization and disinfection']
# ['اعراض الكورنا' 'symptoms']

# %%
test_data[test_data['text'] == 'وصلنا للذروه ولا لسه؟']
# Out:
#                         text              intent
# index
# 54     وصلنا للذروه ولا لسه؟  nothing identified

# %%
misclassified = prevoius_results[prevoius_results['labels'] != last_results['labels']]
misclassified['case'] = test_data[prevoius_results['labels'] != last_results['labels']]['text']
misclassified
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#      index  ...                                               case
# 12      12  ...                 لو حد بيكح من غير سخونية  يعمل ايه
# 22      22  ...                          هنا على اسم مصر وصلت بكام
# 31      31  ...                                  كيف نعالج الكرونا
# 46      46  ...                                 تحليل فيروس كورونا
# 50      50  ...                                         حظر التجول
# 91      91  ...                                               ممكن
# 97      97  ...                                   نعم ، بالتأكيد 👍
# 112    112  ...                                              بعربي
# 138    138  ...  اهلا  أرجو الرد هل موضوع كورونا مفترض أن يمتد ...
# 140    140  ...    ايه الاكلات اللي اعملها لولادي عشان تمنع العدوي
# 145    145  ...                   لو عند درجة حرارة عاليه اعمل ايه
# 151    151  ...                                           هل تحبنى
# 161    161  ...                                             منوفيه
# 167    167  ...              درجات الحراره المتوقعه الايام القادمة
# 168    168  ...                    ماهي فحوصات معرفه انتقال العدوي
# 173    173  ...      هل يمكن زيارة دكتور الأسنان في وجود الكورونا.
# 178    178  ...            ما هو نوع القماش المفضل لعمل ماسك للوجه
# 181    181  ...                                                 ما
#
# [18 rows x 4 columns]

# %%
# prevoius_results.intent.loc[12] = 'assessment'
# prevoius_results.intent.loc[46] = 'laboratory'
# prevoius_results.intent.loc[54] = 'infected cases'
# prevoius_results.intent.loc[97] = 'yes'
# prevoius_results.intent.loc[138] = 'the evolution of the virus'
# prevoius_results.intent.loc[145] = 'assessment'
# prevoius_results.intent.loc[167] = 'warm weather'
# prevoius_results.intent.loc[168] = 'laboratory'
# prevoius_results.intent.loc[173] = 'muzzle/mask'
# prevoius_results.intent.loc[178] = 'muzzle/mask' 
# prevoius_results.intent.loc[187] = 'yes'
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
prevoius_results.loc[97]
# Out:
# index      97
# intent    yes
# labels     30
# Name: 97, dtype: object

# %%
prevoius_results.loc[168]
# Out:
# index            168
# intent    laboratory
# labels            34
# Name: 168, dtype: object

# %%
prevoius_results.drop('labels',axis=1).to_csv('habdmodel.csv', index=False)

# %% [markdown]
# # Preprocessing

# %%
char2index = {' ': 1,'ء': 3,'آ': 4,'أ': 5,'ؤ': 6,'إ': 7,'ئ': 8,'ا': 9,'ب': 10,'ة': 11,'ت': 12,'ث': 13,'ج': 14,'ح': 15,'خ': 16,'د': 17,'ذ': 18,'ر': 19,'ز': 20,'س': 21,'ش': 22,'ص': 23,'ض': 24,'ط': 25,'ظ': 26,'ع': 27,'غ': 28,'ف': 29,'ق': 30,'ك': 31,'ل': 32,'م': 33,'ن': 34,'ه': 35,'و': 36,'ى': 37,'ي': 38,'ڤ':39}

# %%
stop_file =  my_file = open("/content/drive/MyDrive/dataset/arabic_stop_words.txt", "r")
stopwords = stop_file.read().split('\n')

# %%
def clean_text(string):
  string = araby.strip_tashkeel(string)
  #string = araby.normalize_alef(string)
  string = araby.normalize_teh(string)
  #string = araby.normalize_hamza(string)
  string = string = re.sub(r'ء','ا',string)
  string = re.sub(r'[0123456789]*','',string)
  string = re.sub(r'[٠,١,٢,٣,٤,٥,٦,٧,٨,٩,٪,٫,٬,٭,ٮ,ٯ,ٰ,ٱ,ٲ,ٳ,ٴ,ٵ,ٶ,ٷ,ٸ,ٹ,ٺ,ٻ,ټ,ٽ,پ,ٿ,ڀ,ځ,ڂ,ڃ,ڄ,څ,چ,ڇ,ڈ,ډ,ڊ,ڋ,ڌ,ڍ,ڎ,ڏ,ڐ,ڑ,ڒ,ړ,ڔ,ڕ,ږ,ڗ,ژ,ڙ,ښ,ڛ,ڜ,ڝ,ڞ,ڟ,ڠ,ڡ,ڢ,ڣ,ڤ,ڥ,ڦ,ڧ,ڨ,ک,ڪ,ګ,ڬ,ڭ,ڮ,گ,ڰ,ڱ,ڲ,ڳ,ڴ,ڵ,ڶ,ڷ,ڸ,ڹ,ں,ڻ,ڼ,ڽ,ھ,ڿ,ۀ,ہ,ۂ,ۃ,ۄ,ۅ,ۆ,ۇ,ۈ,ۉ,ۊ,ۋ,ی,ۍ,ێ,ۏ,ې,ۑ,ے,ۓ,۔,ە,ۖ,ۗ,ۘ,ۙ,ۚ,ۛ,ۜ,۝,۞,۟,۠,ۡ,ۢ,ۣ,ۤ,ۥ,ۦ,ۧ,ۨ,۩,۪,۫,۬,ۭ,ۮ,ۯ,۰,۱,۲,۳,۴,۵,۶,۷,۸,۹,]*','',string)
  string = re.sub(r'[…"%–_!()*-.ـ:=o«»;\[\]؛,،~?؟\u200f\ufeffـ\u200d\u200c\uf020\uf03a\uf02d\uf02e]*','',string)
  string = re.sub(r'[abcdefghijklmnopqrstuvwx×yzABCDEFGHIJKLMNOPQRSTUVWXYZ]*','',string)
  string = re.sub(r"\s+$", '',string)
  string = re.sub(r"^\s+", '',string)
  string = demoji.replace(string)
  return string

# %%
	
from snowballstemmer import stemmer

def preprocess_text(text,tokenizer=wordpunct_tokenize,stemmer = stemmer('arabic'),stop_words=stopwords):
  print('old string:',text)

  # (1) Cleaning text
  text = clean_text(text)

  # (2) Tokenizing
  text = tokenizer(text)
  
  # (3) Removing stopwords
  text = [word for word in text if word not in stop_words]

  
  # (4) Stemming
  text = [stemmer.stemWord(word) for word in text]
  text = ' '.join(text)
  # (5) Removing duplicate chars
  #text = ["".join(dict.fromkeys(word)) for word in text]

  print('new string:',text)

  return text

# %%
def digitize(string):
  return [char2index[char] for word in string for char in word]

# %%
# # tokenized_matrix = pad_sequences(data['text'].apply(lambda x: digitize(preprocess_text(x))).values,padding='post', value=0, maxlen = 50)
# # tokenized_matrix
# tokenized_matrix = data['text'].apply(lambda x: preprocess_text(x))
# tokenized_matrix
# Out:
# 0                          [شفي, عزل, مصر, وما, هى, مكن]
# 1                                                  [خصم]
# 2                                        [متي, نهي, كور]
# 3                                              [ان, اسف]
# 4                                        [كام, وفي, هرد]
#                              ...
# 786                                                [اهل]
# 787                                                [بلح]
# 788                                                [حال]
# 789                                      [نهى, يرس, كور]
# 790    [مكن, عرف, يتم, نها, يرس, كرو, وهل, تثر, رفع, ...
# Name: text, Length: 791, dtype: object

# %%
_ = data['text'].apply(preprocess_text)
# Out:
# old string: كم عدد مستشفيات العزل فى مصر وما هى اماكنها
# new string: مستشفيا عزل مصر وما هي اما
# old string: ومخاصمك
# new string: مخاصم
# old string: متي ينتهي كورونا؟
# new string: مت ينته كور
# old string: انا اسف
# new string: انا اسف
# old string: كام عدد الوفيات النهارده
# new string: كام الوف نهارده
# old string: عارفه يا نميسا انا عندى ليكى عريس
# new string: عارف يا نميس انا عندي ليكي عريس
# old string: ما هي مرض كرونا والعلاج وطرق الوقابه
# new string: مرض كرو والعلاج طرق وقابه
# old string: عدد الاصابات كرونه فى مصر
# new string: اصاب كرون مصر
# old string: والدي تعبان شويه وصدره بيوجعه مش عارف ده دور برد ولا كورونا ؟
# new string: والد تعبان شوي صدر يوجع مش عارف ده دور برد كور
# old string: عدد الوفيات النهاردة كان في إيطاليا
# new string: الوف نهارده ايطالي
# old string: هل الفيروس كورنا يبقي علي. الملابس. والاحذية
# new string: فيروس كور يبق ملابس والاحذ
# old string: التقرير النهارده كام
# new string: تقرير نهارده كام
# old string: طاهر إزاي البيت والملابس
# new string: طاهر ازا بيت والملابس
# old string: هل مادة الفينيك تقتل الفيروسات بحيث يمكن استخدامها في تطهير العمارات والأسطح؟؟؟
# new string: ماد فينيك تقتل فيروس حيث استخدام تطهير عمار والاسطح
# old string: كم عدد المصابين اليوم في مصر
# new string: مصاب مصر
# old string: ماهى آخر تطورات كورونا فى السعوديه
# new string: ماهي اخر تطورا كور سعوديه
# old string: أهلا ناميسا
# new string: ناميس
# old string: مرحبا
# new string: مرحب
# old string: علاج لدعم المناعة
# new string: علاج لدعم مناعه
# old string: كم عدد الحالات فى قطر
# new string: حال قطر
# old string: الاعداد في الصين
# new string: اعداد صين
# old string: منحنى كورونا فى ايطاليا
# new string: منحني كور ايطالي
# old string: الحالات الجديدة بمصر
# new string: حال جديده مصر
# old string: ممكن اعرف اعراض كورنا
# new string: ممك اعرف اعراض كور
# old string: اعداد الحالات في جنوب أفريقيا و السودان
# new string: اعداد حال جنوب افريقي سود
# old string: النسبه المؤيه بالنسبه لعدد السكان
# new string: نسبه مويه نسبه لعدد السك
# old string: الحالات فى ايطاليا
# new string: حال ايطالي
# old string: اعراض
# new string: اعراض
# old string: درجه الحراري تؤثر علي كورونا
# new string: درج حرار توثر كور
# old string: هل كورنا تنتشر عن طريق الهواء
# new string: كور تنتشر طريق هواا
# old string: كام عدد المصابين في السعودية
# new string: كام مصاب سعوديه
# old string: اشكرك
# new string: اشكر
# old string: ممكن اعرف اعراض الكورونا
# new string: ممك اعرف اعراض كورونا
# old string: ما نسبة الشفاء الي الوفاه في مصر
# new string: نسب شفاا وفاه مصر
# old string: اعراض كرونا الاوليه
# new string: اعراض كرو اوليه
# old string: أنا حاسس إن سخنه عندي صداع
# new string: حاسس سخن عند صداع
# old string: أهلا نميسه
# new string: نميس
# old string: شكرًا
# new string: شكر
# old string: عدد الاصابات
# new string: اصاب
# old string: ماهو كورونا ؟
# new string: ماهو كور
# old string: مصر
# new string: مصر
# old string: الاعداد في فرنسا
# new string: اعداد رنس
# old string: الحالات الإيجابية النهردا كام في مصر
# new string: حال ايجابيه نهردا كام مصر
# old string: انا زعلان أوي
# new string: انا زعلان او
# old string: اخر دواء لكورونا
# new string: اخر دوا لكور
# old string: أنا خايف قوي
# new string: خايف قو
# old string: هل لبس القناع مهم ام لا
# new string: لبس قناع مهم ام
# old string: طرق العدوي
# new string: طرق عدو
# old string: بروتوكول العلاج
# new string: روتوكول علاج
# old string: هل يوجد علاج لفيروس كورونا الان
# new string: يوجد علاج لفيروس كور
# old string: تقرير وزارة الصحة عن اليوم
# new string: تقرير زار صحه
# old string: ما هي مستشفيات العزل في القاهرة ؟
# new string: مستشفيا عزل قاهره
# old string: عدد الحالات الجديدة في السعودية
# new string: حال جديده سعوديه
# old string: في كام حالة في مصر النهاردة نميسة
# new string: كام حال مصر نهارده نميس
# old string: م
# new string:
# old string: ماهي اعداد الاصابة في فرنسا ؟
# new string: ماه اعداد اصابه رنس
# old string: الزيك اهلا ومرحبا بحضراتكم
# new string: زيك اهل مرحب حضرا
# old string: الاعداد
# new string: اعداد
# old string: اعرف ازاي اني مريض كورونا
# new string: اعرف ازا ان مريض كور
# old string: سبل الوقايه
# new string: سبل وقايه
# old string: متتن
# new string: متتن
# old string: كم عدد الاصابات في مصر و الكويت
# new string: اصاب مصر كويت
# old string: ليه توقيت معين ينتهي فيه ؟
# new string: ليه توقي معين ينته
# old string: هل تم التوصل لعلاج لفيروس كورونا
# new string: توصل لعلاج لفيروس كور
# old string: اترك مسافة مقدارها كام بينى وبين شخص اخر
# new string: اتر مساف مقدار كام يني شخص اخر
# old string: هلا
# new string: هلا
# old string: ما هي اضرار فيروس كورونا
# new string: اضرار يروس كور
# old string: والي متي ستستمر الكورونا
# new string: وال مت تستمر كورونا
# old string: اعراض الاصابة بكورونا
# new string: اعراض اصابه كور
# old string: صداع
# new string: صداع
# old string: اهل ممكن العدد تزي
# new string: اهل ممك عدد تز
# old string: آه هي طرق انتقال فيروس كورونا
# new string: طرق انتقال يروس كور
# old string: كيف أحمي نفسي
# new string: احم نفس
# old string: متشكر جدا
# new string: متشكر
# old string: ما الجديد
# new string: جديد
# old string: كيف اطهر
# new string: اطهر
# old string: كام عدد المصابين في أمريكا بالكرونه
# new string: كام مصاب امريك كرونه
# old string: ده كده هيبوظ القماش ممكن طريقة تطهير اخري
# new string: ده كده هيبوظ قماش ممك طريق تطهير اخر
# old string: اندونسيا
# new string: اندونسي
# old string: عاوز اعرف طرق الوقايه من فيرس كرونا
# new string: عاوز اعرف طرق وقايه يرس كرو
# old string: اتمني لكم التوفيق لشباب مصر العظيمه
# new string: اتم لكم توفيق لشباب مصر عظيمه
# old string: ايه الدوله ال مش فيها كورونا
# new string: ايه دوله ال مش كور
# old string: كيفية الوقاية من فيرس كرونة
# new string: كيف وقايه يرس كرون
# old string: انا شاكه ان في حد من الجيران عندو الفيرس ايه الرقم اللي اتصل بيه عشان ابلغهم
# new string: انا شاك حد جير عندو فيرس ايه رقم الل اتصل بيه عشان ابلغ
# old string: انا اسالك ع فيروز كرونا بس
# new string: انا اسال يروز كرو بس
# old string: كم عد الحالات فى امريكا اليوم
# new string: عد حال امريك
# old string: اكبر محافط فيه كرورنا
# new string: اكبر محافط كرور
# old string: طب مفيش حل لسه لي كرونا
# new string: طب مفيش حل لسه لي كرو
# old string: ماهو تحليل pcr
# new string: ماهو تحليل
# old string: كم عدد حالات الكورونا في مصر اليوم
# new string: حالا كورونا مصر
# old string: هل ينتقل ڤيرس كرونا بالهواء
# new string: ينتقل يرس كرو هواا
# old string: عاوز اعرف درجه حرارة المصاب بالكرونا بتبقي كام
# new string: عاوز اعرف درج حرار مصاب كرونا تبق كام
# old string: بالتوفيق ان شاء الله تعالى وربنا يحفظنا جميعاً يارب العالمين
# new string: توفيق شاا الله تعالي ورب يحفظ جميع يارب عالم
# old string: اخويا مدخن بيشرب سجاير كتير ممكن الفيرس يجيلو بسببها ؟
# new string: اخوي مدخ يشرب سجاير كتير ممك فيرس يجيل سبب
# old string: هيا ايه اعراض الاصابة بالكورونا ؟
# new string: ايه اعراض اصابه كورونا
# old string: ماهي عدد الحالات اليومية لمحافظة بورسعيد من ظهور الكرونا فيرس الى الان
# new string: ماه حال يوميه لمحافظ ورسعيد ظهور كرونا يرس
# old string: عايز اشحن الموبايل
# new string: عايز اشح موبايل
# old string: هذه الحالات في مصر ولبنان
# new string: حال مصر لبن
# old string: متى ينتهي كرونا
# new string: ينته كرو
# old string: سمعنا ان ريميدسفير وافيجان وبلاكونيل  هل ده صح
# new string: سمع ريميدسفير وافيج لاكونيل ده صح
# old string: طيب ما أنا سألت كم عدد الحالات في إسرائيل
# new string: طيب سال حال اسراييل
# old string: شكرا نميسه
# new string: شكر نميس
# old string: عدد المصابين في مصر
# new string: مصاب مصر
# old string: الحالات اليوم في مصر
# new string: حال مصر
# old string: اخر اعداد كرونا
# new string: اخر اعداد كرو
# old string: الو
# new string: الو
# old string: عدد المصابين ب كورونا في مصر
# new string: مصاب كور مصر
# old string: عدد الإصابات النهاردة
# new string: اصاب نهارده
# old string: عدد حالات
# new string: حالا
# old string: عدد الحالات النهارده كام با نميسه
# new string: حال نهارده كام با نميس
# old string: ممكن اعمل التحليل فين؟
# new string: ممك اعمل تحليل فين
# old string: اعداد الحالات النهارده في مصر
# new string: اعداد حال نهارده مصر
# old string: طيب الموضوع هيخلص امته
# new string: طيب موضوع هيخلص امت
# old string: ما هي الأعراض
# new string: اعراض
# old string: واو ده انتي معديه
# new string: ده انت معد
# old string: المصابين في مصر والدولة السعودية
# new string: مصاب مصر والدول سعوديه
# old string: اهم التوصيات
# new string: اهم توص
# old string: الحالات في النرويج
# new string: حال نرويج
# old string: كام عدد الحالات فرس كرونا في مصر
# new string: كام حال فرس كرو مصر
# old string: للمصابين في مصر النهاردة كان
# new string: مصاب مصر نهارده
# old string: إسرائيل
# new string: اسراييل
# old string: اسبانيا
# new string: اسباني
# old string: خلاص يا حاجة
# new string: خلاص يا حاج
# old string: آه هي أعراض فيرس كرونة
# new string: اعراض يرس كرون
# old string: عداد الحالات
# new string: عداد حال
# old string: ماهى المساحة بين شخص وشخص تحمى من الإصابة بالفيرس
# new string: ماهي مساحه شخص شخص تحمي اصابه فيرس
# old string: اعداد الحالات في اطاليا و هولاندا
# new string: اعداد حال اطالي هولاند
# old string: عدد الوفيات في كندا
# new string: الوف كند
# old string: وانا شاهدت صاحب فكرة البرنامج مع محمود سعد
# new string: وانا شاهد صاحب فكر برنامج محمود سعد
# old string: لا شكرا
# new string: شكر
# old string: سعال
# new string: سعال
# old string: كم عدد الحالات ف ايطاليا
# new string: حال ايطالي
# old string: كم عدد الحالات المصابة في مصر
# new string: حال مصابه مصر
# old string: ايه أعراض كورونا
# new string: ايه اعراض كور
# old string: لا محافظة المنيا اللى فى مصر مش الدوله
# new string: محافظ منيا اللي مصر مش دوله
# old string: اهلا و ازيك
# new string: اهل ازي
# old string: ما عدد المصابين اليوم في مصر
# new string: مصاب مصر
# old string: عدد إيطاليا
# new string: ايطالي
# old string: ماهو فيروس كورونا؟
# new string: ماهو يروس كور
# old string: نسبه نسبه
# new string: نسب نسب
# old string: ازي افرق بين الصداع العادي والصداع أعراض الكورنا
# new string: از افرق صداع عاد والصداع اعراض كورنا
# old string: لا شكراً
# new string: شكر
# old string: لماذا لا يتم خصم اعداد المتعافين من المرض من عدد الاصابات
# new string: لماذ يتم خصم اعداد متعاف مرض اصاب
# old string: انا بتسأل عن مستشفيات خاصة علشان لا قدر الله موضوع كورونا
# new string: انا تسال مستشفيا خاص علشان قدر الله موضوع كور
# old string: مستشفيات الحجر في مصر
# new string: مستشفيا حجر مصر
# old string: كمان عايز اعرف ايه المقصود بنتائج تحولت حالتها من ايجابيه لسلبيه
# new string: كمان عايز اعرف ايه مقصود نتايج تحول حال ايجاب لسلب
# old string: أساليب الإصابة أساليب الوقاية من الإصابة
# new string: اساليب اصابه اساليب وقايه اصابه
# old string: كام في فلسطين
# new string: كام لسط
# old string: عدد وفيات كورونا وعدد المصابين وفي علاج ليه ًوله لا
# new string: فيا كور عدد مصاب علاج ليه
# old string: كام
# new string: كام
# old string: اعداد الحالات في فرنسا و إسبانيا و الأردن
# new string: اعداد حال رنس اسباني ارد
# old string: طب ينفع تقوليلي العدد الي اتصاب يوم الثلاثاء في مصر
# new string: طب ينفع تقوليل عدد اتصاب ثلاثاا مصر
# old string: برافو
# new string: راف
# old string: لم تجب على سؤالي
# new string: تجب سوال
# old string: العدوي ممكن تنتقل من الهوا لما بنزل الشارع؟
# new string: عدو ممك تنتقل هوا نزل شارع
# old string: لو سمحت اي اللي ممكن يفصل بين وجع الزور العادي و النغرشه و بين الكورونا
# new string: سمح الل ممك يفصل وجع زور عاد نغرشه كورونا
# old string: اسمك
# new string: اسم
# old string: وفايات
# new string: فايا
# old string: اعداد الاصابات
# new string: اعداد اصاب
# old string: أعداد الحالات في مصر آه النهاردة إيه
# new string: اعداد حال مصر نهارده ايه
# old string: الحل
# new string: الحل
# old string: هل أصيب احد بالفيروس في سجون مصرية
# new string: اصيب فيروس سجون مصر
# old string: كام عدد الحالات فى مصر
# new string: كام حال مصر
# old string: ما بعد كروانا  ايه
# new string: كرو ايه
# old string: اهلاا
# new string: اهلا
# old string: ما هى اعراض الاصابه بالكورونا؟
# new string: هي اعراض اصابه كورونا
# old string: ما هو كورونا
# new string: كور
# old string: عندي برد شديد
# new string: عند برد شديد
# old string: هي أعداد الإصابات في مصر ولبنان
# new string: اعداد اصاب مصر لبن
# old string: كم عدد الاصابات في لكويت
# new string: اصاب لكوي
# old string: عدد المصابين مصر
# new string: مصاب مصر
# old string: حالات اليوم
# new string: حالا
# old string: ازيك نميسه
# new string: ازي نميس
# old string: هو شرب الليمون كويس ضد فيروس كرونة
# new string: شرب ليم كويس يروس كرون
# old string: الكويت
# new string: كويت
# old string: انا والدي و والدتي كبار في السن وعندهم الضغط وخايف عليهم جدا يجرالهم حاجه
# new string: انا والد والدت كبار السن عند ضغط خايف علي يجرال حاج
# old string: هي الحالات في السعودية وصلت لك إمبارح
# new string: حال سعوديه وصل لك امبارح
# old string: كم عدد الحالات المصابة بالكورونا اليوم
# new string: حال مصابه كورونا
# old string: ماهى الادوية التي تساعد الجسم ليدافع عن نفسه من كورونا
# new string: ماهي ادويه تساعد جسم ليدافع كور
# old string: معدل اصابات في الجزاير
# new string: معدل اصابا جزاير
# old string: وهي صداع من أعراضه
# new string: صداع اعراض
# old string: في مصر
# new string: مصر
# old string: هل المحشي بيتخن ؟
# new string: محش يتخ
# old string: هل. الاسهال من اعرض. الكورنا
# new string: اسهال اعرض كورنا
# old string: اعمل ايه وانا مضطر انزل الشغل و شغلي كل يوم ف مكان مختلف
# new string: اعمل ايه وانا مضطر انزل شغل شغل مكان مختلف
# old string: كل التقدير والشكر للفكرة الرائعة التى بنى عليها هذا  التطبيق الجيد جدا واشكر المهندس احمد محمود على  هذا التطبيق وربنا يجازيك كل خير
# new string: تقدير والشكر فكره رايعه بني تطبيق جيد واشكر مهندس احمد محمود تطبيق ورب يجاز خير
# old string: الإعداد في مصر ولبنان و السعودية ؟
# new string: اعداد مصر لبن سعوديه
# old string: هو طالما الصيف جه كده الفيرس هينتهي
# new string: صيف جه كده فيرس هينته
# old string: انت مين
# new string: انت مين
# old string: انا اشعر بسخونه فى جسدى
# new string: انا اشعر سخون جسدي
# old string: ايه اخبار التعليم
# new string: ايه اخبار تعليم
# old string: كفية الوقايه من كورونا
# new string: كفي وقايه كور
# old string: اعداد الإصابة في فلسطين
# new string: اعداد اصابه لسط
# old string: اه باعربى
# new string: اه باعربي
# old string: انا درجة حرارتى 39
# new string: انا درج حرارتي
# old string: عدد المصابين في اسرائيل
# new string: مصاب اسراييل
# old string: كم عدد الحالات المسجلة فى مصر
# new string: حال مسجله مصر
# old string: اعراض كورونا ؟؟
# new string: اعراض كور
# old string: ماهو الخط الساخن
# new string: ماهو الخط ساخ
# old string: كام واحد مات من كورونا  النهاردة
# new string: كام مات كور نهارده
# old string: انا عندى صداع ورشح
# new string: انا عندي صداع رشح
# old string: اعراض مرض كرونا
# new string: اعراض مرض كرو
# old string: طرق الوقاية
# new string: طرق وقايه
# old string: فى هولندا
# new string: هولند
# old string: نميسة ممكن اعرف اعداد الوفيات في مصر بالنسبه لباقي الدول العربيه
# new string: نميس ممك اعرف اعداد الوف مصر نسبه لباق دول عربيه
# old string: ايه آخر التطورات فى مصر من فيروس كارونا
# new string: ايه اخر تطور مصر يروس كار
# old string: ما هو تأثير كرونا
# new string: تاثير كرو
# old string: كم عدد المصابين في مصر الان
# new string: مصاب مصر
# old string: كيف يتم الوقاية من كورونا بالرغم من ضرورة التعامل مع الجمهور
# new string: يتم وقايه كور رغم ضرور تعامل جمهور
# old string: سؤالي هو الصداع الشديد والهبوط وكل اعراض الضغط المنخفض مع هزال ف الجسم والتهاب ف الحلق
# new string: سوال صداع شديد والهبوط وكل اعراض ضغط منخفض هزال جسم والتهاب حلق
# old string: انا مش بكح
# new string: انا مش بكح
# old string: الوقايه من كورونه
# new string: وقايه كورون
# old string: هل  تعقيم الشوارع له فايده في مواجهه كورونا
# new string: تعقيم شوارع فايد مواج كور
# old string: هل كورونا سينتهي مع شدة حرارة الطقس
# new string: كور ينته شده حرار طقس
# old string: الوقايه للامراض المزمنه انا مريضه روماتويد
# new string: وقايه امراض مزمنه انا مريض روماتويد
# old string: اسهال
# new string: اسهال
# old string: الدوله التي لم ينتشر به وباء كورونا
# new string: دوله ينتشر وبا كور
# old string: أنا حاسة سخونية و درجة حرارتي عالية ده ممكن يكون برد ولا فيرس كرونة
# new string: حاس سخو درج حرارت عال ده ممك برد يرس كرون
# old string: عدد الوفيات اليوم فى مصر
# new string: الوف مصر
# old string: اهلا وسهلا بك
# new string: اهل سهل بك
# old string: فين بس
# new string: فين بس
# old string: ايه الافلام الاي في السينما دلوقتي ؟
# new string: ايه افلام الا سينما دلوقت
# old string: هل يوجد علاج فعال
# new string: يوجد علاج عال
# old string: أعداد المصابين النهاردة في مصر كام
# new string: اعداد مصاب نهارده مصر كام
# old string: اعداد المصابين النهارده
# new string: اعداد مصاب نهارده
# old string: من فضلكم عاوزة اعرف مدة بقاء فيرس كورونا على الاسطح بشكل دقيق
# new string: فضل عاوز اعرف مده بقا يرس كور اسطح دقيق
# old string: ما نسبة الإصابة اليوم في مصر
# new string: نسب اصابه مصر
# old string: كم عدد حالات تايلاند اليوم
# new string: حالا تايلاند
# old string: علاج فيروس كورونا هيكون متوفر امتي؟
# new string: علاج يروس كور هيكون متوفر امت
# old string: طب انتي تقربي لسيري
# new string: طب انت تقرب لسير
# old string: عددالوفيات فى امريكا
# new string: عددالوفيا امريك
# old string: بلدك؟
# new string: بلد
# old string: كم عدد الاصابات في الهمد
# new string: اصاب همد
# old string: البيان
# new string: الب
# old string: إيه آخر أخبار كورونا في مصر
# new string: ايه اخر اخبار كور مصر
# old string: في في مصر كان واحد مصاب
# new string: مصر مصاب
# old string: نميسة
# new string: نميس
# old string: ماهى مستشفيات الحجر بمصر
# new string: ماهي مستشفيا حجر مصر
# old string: عدد الحالات في السعوديه
# new string: حال سعوديه
# old string: القايمة الرئيسية
# new string: قايمه رييسيه
# old string: ولا يبان انك روبوت
# new string: يبان انك روبو
# old string: اعدد المصابين في  المغرب
# new string: اعدد مصاب مغرب
# old string: عدد الحلات الاجابيه فى امريكا لو سمحت
# new string: الحل اجابيه امريك سمح
# old string: كم عدد الحالات فى مصر
# new string: حال مصر
# old string: هل ممكن اروح المستشفى اقولهم حللولي عشان النفس تقيل
# new string: ممك اروح مستشفي اقول حللول عشان نفس تقيل
# old string: هي أطهر من فيرس كرونة
# new string: اطهر يرس كرون
# old string: دي الحالات حالات كرونة في مصر
# new string: دي حال حالا كرون مصر
# old string: اعداد المصابين
# new string: اعداد مصاب
# old string: اهلل
# new string: اهلل
# old string: هل كورونا خطر على كل الناس
# new string: كور خطر ناس
# old string: هل يوجد مصل لعلاج كورونا
# new string: يوجد مصل لعلاج كور
# old string: أخبار الحالات في مصر إن هو ده
# new string: اخبار حال مصر ده
# old string: تحية شكر وتقدير لكل شاب مصري مبدع
#  وشارك في هذا التطبيق
# new string: تحي شكر تقدير لكل شاب مصر مبدع شار تطبيق
# old string: أخبارك إيه
# new string: اخبار ايه
# old string: كم عدد حالات كورونا اليوم
# new string: حالا كور
# old string: ايه الاكتر اهمية في موضوع كورنا هل ايجاد لقاح ولا علاج في الايام دي
# new string: ايه اكتر اهم موضوع كور ايجاد لقاح علاج ايام دي
# old string: ما هو احتمال زيادة نسبة الاصابات بالفيروس خلال الفترة القادمة
# new string: احتمال زياد نسب اصاب فيروس فتره قادمه
# old string: اشكركم على احترامكم وربنا يجعله في ميزان حسناتكم يارب العالمين
# new string: اشكر احترام ورب يجعل ميزان حسنا يارب عالم
# old string: كيف احمي نفسي من الكورونا
# new string: احم نفس كورونا
# old string: عدد المصابين في العالم
# new string: مصاب عالم
# old string: زي أعمل تحليل فيرس كرونو
# new string: زي اعمل تحليل يرس كرون
# old string: ايه هوا اصل الفيروس؟
# new string: ايه هوا اصل فيروس
# old string: طب اى الى بيقوى المناعه
# new string: طب يقوي مناعه
# old string: اي المتوقع مع كورونا بعد شهر
# new string: متوقع كور شهر
# old string: الحالات في مصر قد ايه ؟
# new string: حال مصر ايه
# old string: عرفت ان ساعات بيظهر طفح جلدي هل دا صحيح
# new string: عرف ساعا يظهر طفح جلد دا صحيح
# old string: نتيجة التحليل سلبيه مع حمل المرض
# new string: نتيج تحليل سلب حمل مرض
# old string: تنصحيني بيه عشان فيرس كرونة
# new string: تنصح بيه عشان يرس كرون
# old string: اعراضه ايه
# new string: اعراض ايه
# old string: بيقعد علي الاسطح كام ساعه
# new string: يقعد اسطح كام ساع
# old string: عدد الإصابات في مصر النهاردة كام ؟
# new string: اصاب مصر نهارده كام
# old string: هل يوجد علاج لمرض كورونا أكيد
# new string: يوجد علاج لمرض كور اكيد
# old string: ما هي عدد حالات الوفيات من كورونا في مصر
# new string: حالا الوف كور مصر
# old string: هل الصداع من أعراض كورونا؟
# new string: صداع اعراض كور
# old string: عايزه اعرف ازاي احتمي وانا في الشارع
# new string: عايز اعرف ازا احتم وانا شارع
# old string: مرحبا نميسه
# new string: مرحب نميس
# old string: امريكا
# new string: امريك
# old string: أهلا بحضرتكم تشرفنا بيكم
# new string: حضر تشرف يكم
# old string: كم عدد حالات المصابين بالمرض فى جمهوريه مصر العربيه
# new string: حالا مصاب مرض جمهور مصر عربيه
# old string: الاسكندرية مستسفى واحد فقط
# new string: اسكندريه مستسفي
# old string: في غضون شهر
# new string: غضون شهر
# old string: ماهي اعداد الاصابة في سنغافورة ؟
# new string: ماه اعداد اصابه نغافور
# old string: الكحه خطر
# new string: كحه خطر
# old string: أعداد الحالات في مصر
# new string: اعداد حال مصر
# old string: إعداد المصابين في لبنان و مصر و السعودية ؟
# new string: اعداد مصاب لبنان مصر سعوديه
# old string: تعليمات
# new string: تعليما
# old string: هنرجع شغلنا امته؟
# new string: هنرجع شغل امت
# old string: خلال ال24الماضية
# new string: الماضيه
# old string: من مخترع هذا الفيروس اللعين؟
# new string: مخترع فيروس اللع
# old string: في أي حالة ظهرت في مصر امس
# new string: حال ظهر مصر
# old string: هو ليه الموقع كله انجليزي
# new string: ليه موقع كله انجليز
# old string: هو طالما الصيف جه كده الفيرس هيتقتل
# new string: صيف جه كده فيرس هيتقتل
# old string: الكحول ال95%مفيد ولا ايه
# new string: كحول مفيد ايه
# old string: ألات في إيطاليا
# new string: الا ايطالي
# old string: انا عندي خمسون سنه وركبت دعامه فى القلب..فهل.يحوز أن. اصوم.ولا.لاء
# new string: انا عند سنه ركب دعام قلبفهليحوز اصومولالا
# old string: أود ان اتعرف علي كم حالات الكرونا اليوم؟
# new string: اود اتعرف حالا كرونا
# old string: اذيك
# new string: اذي
# old string: قصدي يكلموكي
# new string: قصد يكلموك
# old string: مده الحجر بعد الشفاء من كورونا
# new string: مده حجر شفاا كور
# old string: انتى مين
# new string: انتي مين
# old string: طرق التطهير
# new string: طرق تطهير
# old string: مستشفيات العزل
# new string: مستشفيا عزل
# old string: شكراً نميسة
# new string: شكر نميس
# old string: الحالات في قطر
# new string: حال قطر
# old string: ما هى عدد الحالات فى دوله قطر
# new string: هي حال دول قطر
# old string: النمسا اخبار الأصابات
# new string: نمسا اخبار اصاب
# old string: لبنان
# new string: لبنان
# old string: هل تم اختراع علاج لكرونا
# new string: اختراع علاج لكر
# old string: مصابين ١١من أبريل كام في مصر
# new string: مصاب كام مصر
# old string: عدد المصابين كام دلوقتي
# new string: مصاب كام دلوقت
# old string: علامات المرض
# new string: علاما مرض
# old string: ممكن فى ايطاليا
# new string: ممك ايطالي
# old string: عدد حالات مصر النهاردة
# new string: حالا مصر نهارده
# old string: زهقان ايه الحل
# new string: زهقان ايه الحل
# old string: لماذا لايتم خصم الحالات التي تحولت لسلبية والحالات المتوفاه من اجمالي الحالات المصابة بالفيروس؟
# new string: لماذ لاي خصم حال تحول لسلب والحالا متوفاه اجمال حال مصابه فيروس
# old string: قشطه عليكي
# new string: قشط عليك
# old string: اقل دولة فى نسب الوفيات ايه؟
# new string: اقل دول نسب الوف ايه
# old string: ليوم الجمعة كام يا نميسة
# new string: ليوم جمعه كام يا نميس
# old string: عدد الحالات في سلطنة عمان
# new string: حال سلط عمان
# old string: شكرا
# اللي بسأل عليه مش عندك شكرا لتعبك
# new string: شكر الل سال مش عند شكر لتعب
# old string: اعداد المصابين في مصر و الكويت و ايطاليا السعودية لبنان
# new string: اعداد مصاب مصر كويت ايطالي سعوديه لبنان
# old string: أخبار إعداد الفيروس البوم فى مصر
# new string: اخبار اعداد فيروس بوم مصر
# old string: لو عايز اسافر دلوقتى اعمل ايه؟
# new string: عايز اسافر دلوقتي اعمل ايه
# old string: ما عدد إصابات مصر اليوم
# new string: اصابا مصر
# old string: اعمل ايه
# new string: اعمل ايه
# old string: والله شكرا جزيلا وبرنامج رائع شكرا نميسة
# new string: والل شكر جزيل رنامج رايع شكر نميس
# old string: شكرا لك
# ساتحدث في وقت لاحق عندما احتاج لذلك 👍🌹
# new string: شكر لك ساتحدث وقت لاحق احتاج
# old string: كل الهري ده وبرضه ماجوبتش عن السؤال
# new string: الهر ده برض ماجوبتش سوال
# old string: هل مرض كورونا يؤثر على المصابين بالتهاب في الرئة؟
# new string: مرض كور يوثر مصاب تهاب ريه
# old string: كام اعداد إصابات اليوم
# new string: كام اعداد اصابا
# old string: عدد الوفيات اليوم
# new string: الوف
# old string: هو في مصر في كم واحد مصاب
# new string: مصر مصاب
# old string: متقلقيش
# new string: متقلقيش
# old string: إعداد سوهاج
# new string: اعداد سوهاج
# old string: كم عدد الحالات في مصر اليوم
# new string: حال مصر
# old string: كام حالة في مصر
# new string: كام حال مصر
# old string: عدد الحالات المصابة في الهند
# new string: حال مصابه هند
# old string: الحالات في إيطاليا و إنجلترا
# new string: حال ايطالي انجلتر
# old string: اعداد الحالات في الهند
# new string: اعداد حال هند
# old string: هل التهاب الجيوب الأنفية ممكن يسبب كرونا
# new string: تهاب جيوب انفيه ممك يسبب كرو
# old string: علشان تجنب
# new string: علشان تجنب
# old string: عدد الحالات المصابة في ألمانيا
# new string: حال مصابه الماني
# old string: هو أنا لازم ألبس جوانتي
# new string: لازم البس جوانت
# old string: كم عدد الحالات المصابة في الهند
# new string: حال مصابه هند
# old string: شكرًا .. شكرًا .
# new string: شكر شكر
# old string: اعداد المصابين في مصر الان
# new string: اعداد مصاب مصر
# old string: إعداد المصابين فى مصر بسب كارونا
# new string: اعداد مصاب مصر بسب كار
# old string: هل نحن وصلنا إلى الذروة ام لا
# new string: وصل ذروه ام
# old string: كام عدد الاصابه بفيروس مورونا بمصر؟
# new string: كام اصابه فيروس مور مصر
# old string: عربي
# new string: عرب
# old string: تكرار للى معروف
# new string: تكرار للي معروف
# old string: رائع جدًا .. شكرًا جزيلاً .
# new string: رايع شكر جزيل
# old string: اعداد الحالات فى ايطاليا
# new string: اعداد حال ايطالي
# old string: مدة انتشار فيرس عل الاسطح
# new string: مده انتشار يرس اسطح
# old string: اعداد المصابين في إنجلترا و هولندا
# new string: اعداد مصاب انجلتر هولند
# old string: الحظر
# new string: حظر
# old string: اعداد الحالات في أوكرانيا و روسيا
# new string: اعداد حال اوكراني روسي
# old string: إعداد في مصر كام
# new string: اعداد مصر كام
# old string: ما هو كونك
# new string: كون
# old string: اعداد المصابين في مصر
# new string: اعداد مصاب مصر
# old string: دعاء رفع البلاء
# new string: دعا رفع بلاا
# old string: الاسهال عرض
# new string: اسهال عرض
# old string: من الدوله المتسببه ف ظهور فيروس كورونا
# new string: دوله متسببه ظهور يروس كور
# old string: هل يتنقل الفيروس عن طريق ملامسه مقابض السيارة اومقابض جميع الأبواب العامة
# new string: يتنقل فيروس طريق ملامس مقابض سياره اومقابض ابواب عامه
# old string: امتي ينتهي الفيرس
# new string: امت ينته فيرس
# old string: ما آخر المستجدات الدوليه في صنع ماصل او علاج
# new string: اخر مستجد دوليه صنع ماصل علاج
# old string: هل يمكن الاصابة بكورونا دون ملامسة شخص مصاب او الاقتراب منه ؟
# new string: اصابه كور ملامس شخص مصاب اقتراب
# old string: نميسة عايز أعرف عدد الحالات في لبنان
# new string: نميس عايز اعرف حال لبنان
# old string: احنا بقينا كام واحد عنده كرونا دلوقتي
# new string: احنا بقي كام عند كرو دلوقت
# old string: الفيروس ده هنخلص منه أمتي
# new string: فيروس ده هنخلص امت
# old string: ممكن التفاصيل عن تسجيل العماله الغير منتظمه
# new string: ممك تفاصيل تسجيل عماله غير منتظم
# old string: الفرق بين كورونا وااانفانزا
# new string: فرق كور وااانفانز
# old string: كام عدد المصابين في الاسماعيليه
# new string: كام مصاب اسماعيليه
# old string: كيفية الحذر من قرون
# new string: كيف حذر قرون
# old string: كم عدد المصابين في مصر اليوم؟
# new string: مصاب مصر
# old string: جوزي بينزل الشغل كل يوم وفي ناس تعبانه عنده ايه الاعراض اللي تعرفني ان دي عدوي كورونا
# new string: جوز ينزل شغل ناس تعبان عند ايه اعراض الل تعرف دي عدو كور
# old string: هو إيه الفرق بين فيرس كرونو الإنفلونزا العادية
# new string: ايه فرق يرس كرون انفلونزا عاديه
# old string: برافو عليك يا نميسة رفعتي رأسنا والل ه شطورة
# new string: راف يا نميس رفعت راس والل شطور
# old string: وكم عدد المصابين الإجمالي
# new string: وكم مصاب اجمال
# old string: روسيا
# new string: روسي
# old string: تركيا
# new string: تركي
# old string: و ممكن تكون اعراض ربو او ارتجاع مرى
# new string: ممك اعراض ربو ارتجاع مري
# old string: معنديش حاجه
# new string: معنديش حاج
# old string: كن عدد الحالات في المغرب
# new string: حال مغرب
# old string: أشكرك
# new string: اشكر
# old string: من اربع ايام باحس  باحتقان بسيط الصبح وبيروح بعد شويه
# new string: اربع باحس باحتق سيط صبح يروح شوي
# old string: ايه الأكلات اللي اعملها لولادي عشان تمنع العدوي تجلهم
# new string: ايه اكل الل اعمل لولاد عشان تمنع عدو تجل
# old string: كم عدد حالات اليوم
# new string: حالا
# old string: ما هي الكرونا
# new string: كرونا
# old string: كان عدد الإصابات مكرونة في مصر
# new string: اصاب مكرون مصر
# old string: هل في نوع معين من الأكل كويس ضد فيرس كرونة
# new string: نوع معين اكل كويس يرس كرون
# old string: هل هناك امصال ؟
# new string: امصال
# old string: السلام عليكم ورحمة الله وبركاته
# new string: سلام علي رحم الله ركا
# old string: كيفيه التعامل مع الفيرس
# new string: كيف تعامل فيرس
# old string: اهلا نميسة
# new string: اهل نميس
# old string: الفيرس بيفضل عايش قد ايه علي الاسطح
# new string: فيرس يفضل عايش ايه اسطح
# old string: مستقبل كورونا مصر
# new string: مستقبل كور مصر
# old string: شكراً
# new string: شكر
# old string: هل الماسك يحمى من الإصابة بالفيرس
# new string: ماسك يحمي اصابه فيرس
# old string: متوقع  ينتهي متي الوباء كرونا
# new string: متوقع ينته مت وباا كرو
# old string: متى نرجع عملنا
# new string: نرجع عمل
# old string: الحالات في المنوفيه
# new string: حال منوفيه
# old string: السلام عليكم
# new string: سلام علي
# old string: تمام
# new string: تمام
# old string: شكرا يا نموسة
# new string: شكر يا نموس
# old string: اعدد المصابين اليوم في مصر
# new string: اعدد مصاب مصر
# old string: اين توجد مستشفيات العزل؟
# new string: اين توجد مستشفيا عزل
# old string: ما بعد الشفاء
# new string: شفاا
# old string: كوسوفو
# new string: كوسوف
# old string: كم عدد الاصابات في امركا
# new string: اصاب امرك
# old string: اعداد الحالات في فرنسا وإسبانيا و الأردن
# new string: اعداد حال رنس اسباني ارد
# old string: مجهود طيب .. بالتوفيق
# new string: مجهود طيب توفيق
# old string: ما عدد المصابين في مصر
# new string: مصاب مصر
# old string: هل تم الوصول لدواء معين لمعالجة الفيروس
# new string: وصول لدوا معين لمعالج فيروس
# old string: ازاي احمى نفسي من كورونا
# new string: ازا احمي نفس كور
# old string: انا عندي برد
# new string: انا عند برد
# old string: تقرير الإصابات والوفيات
# new string: تقرير اصاب والوفيا
# old string: ازاي الشخص يعرف انه عنده كورونا ايه العلامة المميزه لها
# new string: ازا شخص يعرف عند كور ايه علامه مميزه
# old string: عدد الوفيات في مصر
# new string: الوف مصر
# old string: اي اعراض كرونا
# new string: اعراض كرو
# old string: كم الحالات في كندا
# new string: حال كند
# old string: الاثار المتراكمة بعد الشفاء
# new string: اثار متراكمه شفاا
# old string: اهلا ازيك
# new string: اهل ازي
# old string: آهلآ
# new string: اهلء
# old string: ما هو العلاج الوقائي ضد فيروس كورونا
# new string: علاج وقاء يروس كور
# old string: الاعراض الاولى لإصابة كورونا
# new string: اعراض لاصاب كور
# old string: اعداد الحالات في كل محافظة؟
# new string: اعداد حال محافظ
# old string: الاعداد فى مصر كام
# new string: اعداد مصر كام
# old string: ما إعداد مصابة بهتيم
# new string: اعداد مصاب هتيم
# old string: هي إيه طرق انتقال العدوى
# new string: ايه طرق انتقال عدوي
# old string: الحالات في مصى
# new string: حال مصي
# old string: طرق وقاية احدث من الطرق الحالية
# new string: طرق وقا احدث طرق حاليه
# old string: عدد الحالات في مصر
# new string: حال مصر
# old string: اعراض كرونا
# new string: اعراض كرو
# old string: هل الكمامات ذات الفلتر ومن أشهرها ماركة n95. يمكن استخدامها عدة مرات بعد تعقيمها جيدا بالكحول
# new string: كمام فلتر اشهر مار استخدام عده مرا تعقيم جيد كحول
# old string: عدد الوفيات حالات الكورونا فى مصر
# new string: الوف حالا كورونا مصر
# old string: اهلا وازيك
# new string: اهل واز
# old string: سألت قبل كده
# new string: سال كده
# old string: عدد الحالات
# new string: حال
# old string: السيستم واقع ياحجه
# new string: سيستم واقع ياحج
# old string: الأعراض الخفيفة الكرونة
# new string: اعراض خفيفه كرونه
# old string: كم واحد مصاب في مصر وفي الصين
# new string: مصاب مصر صين
# old string: عايزه تقرير النهارده بس
# new string: عايز تقرير نهارده بس
# old string: كام عدد الحالات في انجولا
# new string: كام حال انجول
# old string: أعراض فيرس كرونة
# new string: اعراض يرس كرون
# old string: اعداد الحالات في ايطاليا
# new string: اعداد حال ايطالي
# old string: الاعراض
# new string: اعراض
# old string: كنت بسأل عن تمرين النفس عايزه اعرف اذا كان صح ولا
# شكرا على المعلومه
# new string: كنت سال تمرين نفس عايز اعرف صح شكر معلومه
# old string: في تحليل فالبيت؟
# new string: تحليل فالبي
# old string: أهلاا
# new string: اهلا
# old string: كم عدد المصابين حاليا
# new string: مصاب
# old string: كيفية تكاثر فيرس كورونا
# new string: كيف تكاثر يرس كور
# old string: إعداد المصابين في مصر والكويت
# new string: اعداد مصاب مصر والكوي
# old string: كم  عدد الاصابات في اران
# new string: اصاب اران
# old string: المانيا
# new string: مانيا
# old string: عدد الإصابات في مصر حسب المحافظات
# new string: اصاب مصر محافظ
# old string: هل السعال فقط من أعراض كورنا
# new string: سعال اعراض كور
# old string: هممم
# new string: هممم
# old string: كم عدد الحالات في السعودية
# new string: حال سعوديه
# old string: انا بعمل لك functional test
# new string: انا عمل لك
# old string: يقال انه فيه علاج توصلو اليه هل هذا صحيح
# new string: يقال علاج توصل صحيح
# old string: المغرب
# new string: مغرب
# old string: وهل يتأثر مرض حساسية الجيوب الأنفية بالفيرس
# new string: وهل يتاثر مرض حساس جيوب انفيه فيرس
# old string: اخر الاعداد
# new string: اخر اعداد
# old string: كيف نتعامل مع المشتريات قبل دخول المنزل
# new string: نتعامل مشتر دخول منزل
# old string: ما هو فيروس الكرونا
# new string: يروس كرونا
# old string: شكرا لحضرتكم
# new string: شكر لحضر
# old string: الاعداد في مصر
# new string: اعداد مصر
# old string: طرق تطهير الخضروات
# new string: طرق تطهير خضرو
# old string: الإجراءات الاحترازية
# new string: اجراا احترازيه
# old string: طيب ايه فرق كورونا عن الانفلونزا
# new string: طيب ايه فرق كور انفلونزا
# old string: اعقم البيت ازاي واستخدم انهي كحول
# new string: اعقم بيت ازا واستخدم انه كحول
# old string: ازيك 😍
# new string: ازي
# old string: هل نحن فى أمان
# new string: امان
# old string: هل الكورونا ممكن يتحول لمرض موسمي ؟
# new string: كورونا ممك يتحول لمرض موسم
# old string: كيف اعرف اذا كان عندى كورونا ولا لأ؟
# new string: اعرف عندي كور لء
# old string: ما هو موعد انقضاء الوباء
# new string: موعد انقضا وباا
# old string: لو عندي سخونية
# new string: عند سخو
# old string: انا بسأل على علاج
# new string: انا سال علاج
# old string: كم يوم بيفضل الفايروس على الاسطح
# new string: يفضل فايروس اسطح
# old string: الحالات في تركيا
# new string: حال تركي
# old string: مص
# new string: مص
# old string: ف حجر المسافرين من ليبي
# new string: حجر مسافر ليب
# old string: عدد المصابين النهارده في نصر
# new string: مصاب نهارده نصر
# old string: شكرا لحضرتك وجزاكم الله خيرا
# new string: شكر لحضر وجز الله خير
# old string: بيان وزارة الصحة
# new string: يان زار صحه
# old string: هل تم اكتشاف علاج
# new string: اكتشاف علاج
# old string: ايه الاكلات اللي تقوي من مناعه ولادي
# new string: ايه اكل الل تقو مناع لاد
# old string: صباح الخير
# new string: خير
# old string: مدي فاعليه الخل في القضاء علي الفيروس
# new string: مد فاعل الخل قضاا فيروس
# old string: كام حاله في السويد
# new string: كام حال سويد
# old string: عامله اي
# new string: عامل
# old string: انتى منين
# new string: انتي منين
# old string: الصين
# new string: صين
# old string: الحالات في السعوديه وصلت لكام
# new string: حال سعوديه وصل لكام
# old string: عدد الحالات في مصر حتي الان
# new string: حال مصر حت
# old string: إعداد الحالات
# new string: اعداد حال
# old string: اعداد الحالات
# new string: اعداد حال
# old string: كام عدد حالات مصر
# new string: كام حالا مصر
# old string: هذه الحالات في أمريكا
# new string: حال امريك
# old string: فلسطين
# new string: لسط
# old string: هل لو جالى كحه اتصرف ازاى
# new string: جالي كحه اتصرف ازاي
# old string: يا نميسة من صنعك
# new string: يا نميس صنع
# old string: اخبار كورنا ايه
# new string: اخبار كور ايه
# old string: لا مش الحضانه, الموضوع كله هيخلص امته
# new string: مش حضانه موضوع كله هيخلص امت
# old string: اهلا يا نميسة🤣
# new string: اهل يا نميس
# old string: هل مرض كورونا في مصر وصل لذروته
# new string: مرض كور مصر وصل لذرو
# old string: كأم عدد الحالات فى محافظة المنيا
# new string: كام حال محافظ منيا
# old string: الحالات فى ايران
# new string: حال ايران
# old string: صباح الخير 😊
# new string: خير
# old string: هل هناك اي علاج او مصل ؟
# new string: علاج مصل
# old string: رأي لإنقاص
# new string: رء لانقاص
# old string: عندي الم في الصدر
# new string: عند الم صدر
# old string: كيف حالك يا نميسة
# new string: حال يا نميس
# old string: كم عدد الحالات اليوم
# new string: حال
# old string: ماليزيا
# new string: ماليزي
# old string: كم سعر الدولار
# new string: سعر دولار
# old string: عايزة أعرف الحالة إلي أحنا فيها والقلق حينتهي أمتي
# new string: عايز اعرف حاله احنا والقلق حينته امت
# old string: الام في الرقبة
# new string: الام رقبه
# old string: اي اعداد الاصابات في مصر النهارده
# new string: اعداد اصاب مصر نهارده
# old string: كام عدد الحالات الجديدة في السعودية؟
# new string: كام حال جديده سعوديه
# old string: ما هي الأعراض التي تؤكد الإصابة بكورونا
# new string: اعراض توكد اصابه كور
# old string: محتاج اعرف الاعراض الاوليه لكرونا
# new string: محتاج اعرف اعراض اوليه لكر
# old string: اهلاً
# new string: اهل
# old string: الفيرس بيجي للاطفال ولا الناس الكبيره بس
# new string: فيرس بيج اطفال ناس كبيره بس
# old string: عاوز اعراض كرونا وخاصه المرحله الاولي
# new string: عاوز اعراض كرو خاص مرحله اول
# old string: طيب
# new string: طيب
# old string: ايه
# new string: ايه
# old string: ايه هو الفرق
# new string: ايه فرق
# old string: شكرا لكي
# new string: شكر لك
# old string: اعداد الإصابة في مصر وصل كام
# new string: اعداد اصابه مصر وصل كام
# old string: طفشت من قعدة البيت
# new string: طفش قعد بيت
# old string: وحشتيني يا غالية
# new string: حشت يا غال
# old string: السلام عليكم  ازيك
# new string: سلام علي ازي
# old string: ممكن اعرف اخر الأعداد الخاصة بإصابات فيروس كورونا اليوم
# new string: ممك اعرف اخر اعداد خاصه اصابا يروس كور
# old string: من  انتم؟
# new string: انتم
# old string: شغل حلو
# new string: شغل حلو
# old string: شكرا لذوقك
# new string: شكر لذوق
# old string: هل المرض ينقل عن طريق الهواء
# new string: مرض ينقل طريق هواا
# old string: الأعراض الاساسيه لفيروس كورونا
# new string: اعراض اساسيه لفيروس كور
# old string: وكمان الحلات الى خفت
# new string: كمان الحل خفت
# old string: شكلك غبية
# new string: شكل غبي
# old string: اهلا بكم
# new string: اهل بكم
# old string: الحالات في امريكا ؟
# new string: حال امريك
# old string: عن طريق الاختلاط
# new string: طريق اختلاط
# old string: وقف الحظر امتي
# new string: حظر امت
# old string: باي
# new string: با
# old string: نعم
# new string:
# old string: ماهى طرق تجنب العدوي وكيف احمى نفسى
# new string: ماهي طرق تجنب عدو كيف احمي نفسي
# old string: ماهي افضل طريقه للتطهير
# new string: ماه افضل طريق تطهير
# old string: هو الفيرس بينتقل في الجو
# new string: فيرس ينتقل الجو
# old string: كم عدد الحالات الاسكندريه
# new string: حال اسكندريه
# old string: لو حد جتلة كحة شديدة وبحة صوت و ضيقة نفس بس مافيش سخونة ولا بلغم وعمل أشعة على الصدر ومافيش حاجة ممكن تكون كورونا رغم رفض الحميات استقبالة
# new string: حد جتل كحه شديد وبح صوت ضيق بس مافيش سخون لغم عمل اشع صدر مافيش حاج ممك كور رغم رفض الحم استقبال
# old string: أعداد المصابين فى مصر
# new string: اعداد مصاب مصر
# old string: إعداد الحالات
# new string: اعداد حال
# old string: ما هي أعراض كورونا
# new string: اعراض كور
# old string: انت منين نميسه
# new string: انت منين نميس
# old string: هل الاصابه تأتي بالمخالط لحالة اصابه فقط
# new string: اصابه تات مخالط لحال اصاب
# old string: ماهو السيناريو القادم للاصابة في مصر
# new string: ماهو سيناريو قادم اصابه مصر
# old string: تقرير إعداد المصابين فى مصر بسب كارونا
# new string: تقرير اعداد مصاب مصر بسب كار
# old string: شكرا جدا
# new string: شكر
# old string: هي إيه طرق التطهير الكويسة عشان في روسكورو
# new string: ايه طرق تطهير كويسه عشان روسكور
# old string: هو الحظر اتجدد؟
# new string: حظر اتجدد
# old string: بقينا كام مصاب لحد دلوقتي ؟
# new string: بقي كام مصاب لحد دلوقت
# old string: انا كويسه يا نميسه انتى عامله ايه
# new string: انا كويس يا نميس انتي عامل ايه
# old string: هل الحيوانات تصاب بفيروس
# new string: حيوان تصاب فيروس
# old string: انا تعبانه من قبل المطر ومازلت مريضه
# new string: انا تعبان مطر مازل مريض
# old string: آه فيكم إصابة كرونة في العالم لحد دلوقتي
# new string: يكم اصاب كرون عالم لحد دلوقت
# old string: كم عدد الإصابات القرون في مصر
# new string: اصاب القر مصر
# old string: أهلاً
# new string:
# old string: نعم ، بالتأكيد 👍
# new string: تاكيد
# old string: العامة
# new string: عامه
# old string: معلش انا بسال عن اليوم فقط
# مش الحالات كلها
# new string: معلش انا سال مش حال كله
# old string: نسب الوفيات فى قطر؟
# new string: نسب الوف قطر
# old string: هل ممكن ارسال المعلومات باللغة العربية
# new string: ممك ارسال معلوم لغه عربيه
# old string: بخصوص كرونا
# new string: خصوص كرو
# old string: كورونا*
# new string: كور
# old string: عدد حالات الكرونا في قطر
# new string: حالا كرونا قطر
# old string: الحجر المنزلي
# new string: حجر منزل
# old string: اعداد المصابين📊
# new string: اعداد مصاب
# old string: لو تعاملت مع شخص مصاب جديد  لم تظهر عليه علامات المرض. هل الكمامه والجوانتي يكفوا للحمايه م العدوي؟
# new string: تعامل شخص مصاب جديد تظهر علاما مرض كمامه والجوانت يكف حمايه عدو
# old string: كم حاله امس
# new string: حال
# old string: أو على الأصابات في مدينة أسوان في لكورونا
# new string: اصاب مدين اسوان لكور
# old string: شكرا على الإفادة والمجهود العظيم خالص تقديرى واحترامي لكم مع مزيد من النجاح
# new string: شكر افاده والمجهود عظيم خالص تقديري واحترام لكم مزيد نجاح
# old string: أشعر بالم في الصدر. هل هذا من اعراض الكرونا
# new string: اشعر بالم صدر اعراض كرونا
# old string: اللقاح
# new string: لقاح
# old string: عدد الاصابات فى مصر
# new string: اصاب مصر
# old string: فى دولة ف العالم ماصابها الفيروس
# new string: دول عالم ماصاب فيروس
# old string: ايه الاعراض
# new string: ايه اعراض
# old string: اي محافظات تم اكتشاف حلات فيها
# new string: محافظا اكتشاف حلا
# old string: الوقايه
# new string: وقايه
# old string: في جده
# new string: جده
# old string: شكرا
# new string: شكر
# old string: هل الماسك القماش صحي للتعامل مع الكورونا
# new string: ماسك قماش صح تعامل كورونا
# old string: فرنسا
# new string: رنس
# old string: كلنا كدا بالحجر المنزلى
# new string: كلنا كدا حجر منزلي
# old string: الحالات المصابة
# new string: حال مصابه
# old string: انت جميل
# new string: انت جميل
# old string: لو في عطس لاكتر من مره هل في قلق؟؟
# new string: عطس لاكتر مره قلق
# old string: زي أعمل تحليل فيرس كرونة
# new string: زي اعمل تحليل يرس كرون
# old string: ازيك
# new string: ازي
# old string: التنفس زاى
# new string: تنفس زاي
# old string: كنت محتاج تقرير كامل بالحالات حول العالم
# new string: كنت محتاج تقرير كامل حال عالم
# old string: متى ترجع الامور كما كانت فى مصر قبل كرونا؟
# new string: ترجع امور مصر كرو
# old string: إزيك
# new string: ازي
# old string: عشان المصريين هما اللي هيشتغلوكي
# new string: عشان مصر الل هيشتغلوك
# old string: قطر
# new string: قطر
# old string: ايه هي الكرونا
# new string: ايه كرونا
# old string: نسبة الكحول كام
# new string: نسب كحول كام
# old string: موضوع كورونا سينتهي متي ؟
# new string: موضوع كور ينته مت
# old string: سرعة القذف
# new string: سرع قذف
# old string: إيه هو عدد وفيات مصر النهاردة منك رنه
# new string: ايه فيا مصر نهارده منك رنه
# old string: اعداد المصابين فى الشرفيه
# new string: اعداد مصاب شرفيه
# old string: ممكن تقوليلي يا نميسه  هل لبس الماسكات مهم ولا لأ
# new string: ممك تقوليل يا نميس لبس ماسك مهم لء
# old string: هل حقيقي خبر ان في دواء بامريكا تم اكتشافه وهيظهر بعد اسبوع ام ان هذه اشاعة
# new string: حقيق خبر دوا بامريك اكتشاف هيظهر اسبوع ام اشاع
# old string: كم عدد حالات المصابين بالمرض فى جمهوريه مصر العربيه اليوم
# new string: حالا مصاب مرض جمهور مصر عربيه
# old string: هما الناس اللي بيجيلها الفيرس بتتعزل فين ؟
# new string: ناس الل يجيل فيرس تتعزل فين
# old string: شكرا
# new string: شكر
# old string: عارفة ليه ؟
# new string: عارف ليه
# old string: كام عدد المصابين الآن في مصر بفيروس كرونا
# new string: كام مصاب مصر فيروس كرو
# old string: متي ننتهي من هذا الوباء
# new string: مت ننته وباا
# old string: اهلا ناميسا
# new string: اهل ناميس
# old string: اعداد اليوم
# new string: اعداد
# old string: عاطيب امريكا رايحه على فين؟
# new string: عاطيب امريك رايح فين
# old string: الاردن
# new string: ارد
# old string: العلاج
# new string: علاج
# old string: اعداد الإصابات في امريكا و اطاليا امبارح ؟
# new string: اعداد اصاب امريك اطالي امبارح
# old string: كوسوفو
# new string: كوسوف
# old string: اعداد المصابين فى العالم
# new string: اعداد مصاب عالم
# old string: كيفيه التعامل مع الشنط والاغراض التي يتم شرائها
# new string: كيف تعامل شنط والاغراض يتم شراء
# old string: وهل درجه الحراره هتنيهيه
# new string: وهل درج حراره هتنيه
# old string: كم عدد الحالات المتوقع ظهرها في مصر
# new string: حال متوقع ظهر مصر
# old string: طبعا هيقولو دي مش اعراض كورونا
# new string: طبع هيقول دي مش اعراض كور
# old string: شكرا نميسة
# new string: شكر نميس
# old string: العرف ازاي اني مصابه بالكورونا
# new string: عرف ازا ان مصاب كورونا
# old string: الهند
# new string: هند
# old string: دواء
# new string: دوا
# old string: الحالات فى مصر
# new string: حال مصر
# old string: أخبار جديده
# new string: اخبار جديد
# old string: هل كورونا ينتشر عبر الهواء ؟
# new string: كور ينتشر عبر هواا
# old string: انا احبك نميسة
# new string: انا احب نميس
# old string: فيروس كورونا
# new string: يروس كور
# old string: كحه
# new string: كحه
# old string: الحالات فى الصين
# new string: حال صين
# old string: شكرا ليكم
# new string: شكر ليكم
# old string: سلام عليكم
# new string: سلام علي
# old string: نميسة
# new string: نميس
# old string: اهلا 😊
# new string: اهل
# old string: اعرض االمرض
# new string: اعرض االمرض
# old string: كم عدد المصابين فى مصر الان
# new string: مصاب مصر
# old string: بوت محترم اوى
# new string: بوت محترم اوي
# old string: اقصد ايه اعراض كروانا  انا يوم وتاني يوم
# new string: اقصد ايه اعراض كرو انا وتا
# old string: انا اشعر بهمدان جسم وانا لا انام نوم منتظم بما تنصحيني
# new string: انا اشعر همد جسم وانا انام نوم منتظم بما تنصح
# old string: الحالات اليوم
# new string: حال
# old string: كورونا هيخلص إمتي
# new string: كور هيخلص امت
# old string: اماكن الحجر الصحي في مصر
# new string: اما حجر الصح مصر
# old string: الإعداد في مصر و قطر
# new string: اعداد مصر قطر
# old string: مصر والسعوديه
# new string: مصر والسعود
# old string: دولة كوسوفو
# new string: دول كوسوف
# old string: كام عدد الحالات في الكويت وقطر
# new string: كام حال كويت قطر
# old string: المصابين قد إيه النهاردة
# new string: مصاب ايه نهارده
# old string: إيه هو أسوأ سيناريو ممكن يحصل لمصر
# new string: ايه اسوء ينار ممك يحصل لمصر
# old string: أهلاً .
# new string:
# old string: ازاى اعرف اذا كان عندى كورونا ولا لا؟
# new string: ازاي اعرف عندي كور
# old string: العدوي ممكن تتنقلي من الهوا لما بنزل الشارع
# new string: عدو ممك تتنقل هوا نزل شارع
# old string: ما هو قرونه
# new string: قرون
# old string: أعراض مواد القروض
# new string: اعراض مواد قروض
# old string: حميات
# new string: حميا
# old string: كم عدد المصابين النهاردة يا نميسة في مصر؟
# new string: مصاب نهارده يا نميس مصر
# old string: ايه آخر أخبار كرونا
# new string: ايه اخر اخبار كرو
# old string: بالعربي
# new string: عرب
# old string: ما فيش اخبار عن أي مصر أو أي دواء
# new string: فيش اخبار مصر دوا
# old string: أعراض مرض كورنا
# new string: اعراض مرض كور
# old string: هاي
# new string: ها
# old string: كام عدد مصبين كرونا في مصر
# new string: كام مصبين كرو مصر
# old string: عندى سعال  مصاحب ببلغم هل كده تبقى كورونا
# new string: عندي سعال مصاحب بلغم كده تبقي كور
# old string: اعراض الكرونا
# new string: اعراض كرونا
# old string: طيب ماذا عن المصل ؟
# new string: طيب مصل
# old string: هل الكمامات ذات الفلتر ومن أشهرها n95. هل تستخدم عدة مرات بعد تعقيمها جيدا بالكحول ام لا
# new string: كمام فلتر اشهر استخدم عده مرا تعقيم جيد كحول ام
# old string: سألتها ما هي علامات المرض ؟
# new string: سال علاما مرض
# old string: اعرف ازاي اني مصاب
# new string: اعرف ازا ان مصاب
# old string: السودان
# new string: سود
# old string: عدد الحالات الجديدة في مصر
# new string: حال جديده مصر
# old string: ازيك ناميسه
# new string: ازي ناميس
# old string: اهلا ومرحبا
# new string: اهل مرحب
# old string: اعقم البيت ازاي واستخدم انهي كحول ؟
# new string: اعقم بيت ازا واستخدم انه كحول
# old string: طب انتي ذكية؟
# new string: طب انت ذكي
# old string: ينفع اسال علي اي حاجه تاني
# new string: ينفع اسال حاج تان
# old string: كفاءة 😂
# new string: كفا
# old string: الحالات الجديدة
# new string: حال جديده
# old string: عدد الاصابات بكرونا اليوم في السعودبة
# new string: اصاب بكر سعودبه
# old string: ما هي أعراض المرض
# new string: اعراض مرض
# old string: عدد حالات اليوم
# new string: حالا
# old string: سلام
# new string: سلام
# old string: كم عدد الحالات في مصر
# new string: حال مصر
# old string: الدوا إمتي ؟
# new string: دوا امت
# old string: ايه الاخبار يا نميسة
# new string: ايه اخبار يا نميس
# old string: الاعداد فى روسيا كام
# new string: اعداد روسي كام
# old string: الحالات في كولومبيا
# new string: حال كولومبي
# old string: هل الأحسن ألبس ماسك ولا لأ
# new string: احس البس ماس لء
# old string: طيب في الأردن كام حالة
# new string: طيب ارد كام حال
# old string: أقصد يعني هي ليه عارض من اول يوم
# new string: اقصد يعن ليه عارض
# old string: هل التدخين لقب فيروس كرونة
# new string: تدخ لقب يروس كرون
# old string: ممكن اعرف اخر مستجدات كورونا
# new string: ممك اعرف اخر مستجدا كور
# old string: من فضلك لو حد حرارته بتبقي الصبح ٣٧ وباليل بتطلع ٣٧ و٦ شرط بس مفيش تعب أو حاجه ده عادي
# new string: فضل حد حرار تبق صبح باليل تطلع شرط بس مفيش تعب حاج ده عاد
# old string: عدد الحالات في إسرائيل
# new string: حال اسراييل
# old string: وطرق الوقايه
# new string: طرق وقايه
# old string: حالات النهاردة
# new string: حالا نهارده
# old string: عدد الحالات فی اسبانیا
# new string: حال اسب
# old string: ما هي وسائل الوقايه من فيرس كورونا المستجد
# new string: سايل وقايه يرس كور مستجد
# old string: ما هي المواد التي يمكن وضعها في الرشاش المستخدم في التعقيم في المنزل و ما التركيزات؟
# new string: مواد وضع رشاش مستخدم تعقيم منزل تركيز
# old string: عدد الوفيات
# new string: الوف
# old string: ما سبب الحرقان المستمر ف الزرو مع الريق الناشف
# new string: سبب حرق مستمر زرو ريق ناشف
# old string: هو الأحسن ألبس جوانتي ولا لا
# new string: احس البس جوانت
# old string: التاريخ المتوقع لانتهاء فيرس كرونا فى مصر
# new string: تاريخ متوقع لانتها يرس كرو مصر
# old string: انتو بلح
# new string: انتو بلح
# old string: اه
# new string: اه
# old string: الحجر الصحي بأبوقير الإسكندرية
# new string: حجر الصح ابوقير اسكندريه
# old string: ايه عالامات المرض
# new string: ايه عالاما مرض
# old string: كيف يكون الحجر الصحي
# new string: حجر الصح
# old string: طرقرالوقايه
# new string: طرقرالوقا
# old string: سلبيات كورونا
# new string: سلبيا كور
# old string: حالات انهارده
# new string: حالا انهارد
# old string: ايه نوع الكحول اللي اعقم بيه البيت
# new string: ايه نوع كحول الل اعقم بيه بيت
# old string: الصداع والضغط الواطي من اعراض كرونا
# new string: صداع والضغط واط اعراض كرو
# old string: ما هي فكرة الأهرامات
# new string: فكر اهرام
# old string: شكرا لحضرتك
# new string: شكر لحضر
# old string: انا بسال عن محافظة نعينة
# new string: انا سال محافظ نعين
# old string: كيف تنتقل العدوي بفيروس كورونا
# new string: تنتقل عدو فيروس كور
# old string: إعداد المصابين
# new string: اعداد مصاب
# old string: ماهي الفحوصات المطلوبه لمعرفه وجود الفيروس
# new string: ماه فحوص مطلوبه لمعرف جود فيروس
# old string: انا بكح
# new string: انا بكح
# old string: شكرا ♥️
# new string: شكر
# old string: نموستي سمسوونتي
# new string: نموست سمسوونت
# old string: الوقايه من كرونا
# new string: وقايه كرو
# old string: اعداد الحالات في إسرائيل
# new string: اعداد حال اسراييل
# old string: الفرق بين الانفلونزا والكورونا
# new string: فرق انفلونزا والكور
# old string: حالات النمسا
# new string: حالا نمسا
# old string: انا اسمي مايكل و حابب اعرفك اكتر يانميسة هانم ❤️
# new string: انا اسم مايكل حابب اعرف اكتر يانميس هانم
# old string: عدد المصابين في مصر يوم 13
# new string: مصاب مصر
# old string: آخر أخبار كورونا في مصر
# new string: اخر اخبار كور مصر
# old string: اي المحافظات المصرية ظهرت بها حالات إصابة وعدد الوفيات
# new string: محافظ مصريه ظهر حالا اصاب عدد الوف
# old string: ماهي اعداد الاصابة في ايطاليا ؟
# new string: ماه اعداد اصابه ايطالي
# old string: طيب ليه مش بتجاوبي عن تقرير إسرائيل
# new string: طيب ليه مش تجاوب تقرير اسراييل
# old string: الحالات في مصر
# new string: حال مصر
# old string: كيفيه الوقاية من كورونا
# new string: كيف وقايه كور
# old string: هل تم الوصول الي مصل ضد فيروس كورونا
# new string: وصول مصل يروس كور
# old string: البرتغال
# new string: برتغال
# old string: ايه النظام
# new string: ايه نظام
# old string: انا بتحرك كتير بحكم شغلي.  بس بتحرك بعربيتي   الخاصه. بس ممكن اعمل ايه اول ما ارجع البيت
# new string: انا تحر كتير حكم شغل بس تحر عربيت خاصه بس ممك اعمل ايه ارجع بيت
# old string: اوعدك انك هتبقي اذكي chatbot في العالم
# new string: اوعد انك هتبق اذك عالم
# old string: أهلا ناميسه
# new string: ناميس
# old string: هل كلبي ممكن ينقل لي الفيوس
# new string: كلب ممك ينقل لي فيوس
# old string: الحالات وصلت لكام في اسبانيا
# new string: حال وصل لكام اسباني
# old string: اعداد الحالات في قطر
# new string: اعداد حال قطر
# old string: في امريكا
# new string: امريك
# old string: الحالات فى الأردن
# new string: حال ارد
# old string: حماده اوى
# new string: حماد اوي
# old string: ايه الرقم اللي نتصل بيه لو في حد جاله الفيرس وحالته صعبه
# new string: ايه رقم الل نتصل بيه حد جال فيرس حال صعب
# old string: ايه الغباء ده
# new string: ايه غباا ده
# old string: كم عدد الحالات في كندا
# new string: حال كند
# old string: هل اثبت اي علاج للكورونا حتي الان فعاليته في القضاء عليها
# new string: اثب علاج كورونا حت عالي قضاا
# old string: حالات كورونا الجديده بمصر
# new string: حالا كور جديده مصر
# old string: شكرا جزيلا بصراحة خدمة كويسه جدا
# new string: شكر جزيل صراح خدم كويس
# old string: عدد حالات وفيات الكورونا فى مصر والدول العربية
# new string: حالا فيا كورونا مصر والدول عربيه
# old string: كم عدد المصابين بمصر الان
# new string: مصاب مصر
# old string: شكرا يا نمسية
# new string: شكر يا نمس
# old string: إزاي أطهر البيت
# new string: ازا اطهر بيت
# old string: كم عدد المصابين بكرونا اليوم بمصر
# new string: مصاب بكر مصر
# old string: متي يتوقف فيروس كورونا ؟
# new string: مت يتوقف يروس كور
# old string: ايران وتركيا بريطانيا
# new string: ايران تركي ريطاني
# old string: اعراض مرض الكرونه
# new string: اعراض مرض كرونه
# old string: اعداد المصابين فى مصر اليوم
# new string: اعداد مصاب مصر
# old string: كيف يمكن التواصل معكم؟
# new string: تواصل معكم
# old string: ما هي اعراض المرض
# new string: اعراض مرض
# old string: ازاي اعرف لو حد مريض كورونا او لا
# new string: ازا اعرف حد مريض كور
# old string: عدد حالات مصر النهارده
# new string: حالا مصر نهارده
# old string: أيوه ده ايه علاقته بالسؤال؟
# new string: ايو ده ايه علاق سوال
# old string: هاى
# new string: هاي
# old string: ازاى اتجنب الفيرس
# new string: ازاي اتجنب فيرس
# old string: كام عدد الحالات فى امريكا
# new string: كام حال امريك
# old string: انا اعرف ازاى انا عندى الكورونا
# new string: انا اعرف ازاي انا عندي كورونا
# old string: الاشعه المقطعيه علي الصدر تدل علي وجود المرض
# new string: اشعه مقطعيه صدر تدل جود مرض
# old string: انتى مين ؟
# new string: انتي مين
# old string: طيب عايزه اي اساليب اتبعها عشان اقدر احمي عيالي
# new string: طيب عايز اساليب اتبع عشان اقدر احم عيال
# old string: أهلا وسهلا
# new string: سهل
# old string: اهلا
# new string: اهل
# old string: بلح
# new string: بلح
# old string: كم عدد الحالات
# new string: حال
# old string: متى ينتهى فيروس كورونا
# new string: ينتهي يروس كور
# old string: ممكن اعرف متى يتم الانتهاء من فيرس كرونا وهل يتأثر بارتفاع درجة الحرارة
# new string: ممك اعرف يتم انتهاا يرس كرو وهل يتاثر بارتفاع درج حراره

# %% [markdown]
# # New Preprocessing

# %%
# import torch
# from transformers import XLMRobertaTokenizer

# # Download the tokenizer for the XLM-Robert `base` model.
# tokenizer = XLMRobertaTokenizer.from_pretrained("xlm-roberta-base" )
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=5069051.0, style=ProgressStyle(descript…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=9096718.0, style=ProgressStyle(descript…

# %%
# # Retrieve the full list of tokens.
# all_tokens = list(tokenizer.get_vocab().keys())

# print('The vocabulary contains {:,} tokens.'.format(len(all_tokens)))

# %%
# from transformers import BertTokenizer

# # Download the tokenizer for the XLM-Robert `base` model.
# bert_tokenizer = BertTokenizer.from_pretrained("bert-base-cased")
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=213450.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=29.0, style=ProgressStyle(description_w…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=435797.0, style=ProgressStyle(descripti…

# %%
# example_sentence = 'برجاء ايقا فمتا الهراء'

# # Tokenize with SentencePiece
# xlmr_tokens = tokenizer.tokenize(example_sentence)

# # Tokenize with WordPiece
# bert_tokens = bert_tokenizer.tokenize(example_sentence)

# %%
# from transformers import XLMRobertaForSequenceClassification
# # Load the tokenizer. 
# xlmr_tokenizer = XLMRobertaTokenizer.from_pretrained("xlm-roberta-base" )
# # Load the model.
# xlmr_model = XLMRobertaForSequenceClassification.from_pretrained("xlm-roberta-base", num_labels=40)

# %%
import torch

# If there's a GPU available...
if torch.cuda.is_available():    

    # Tell PyTorch to use the GPU.    
    device = torch.device("cuda")

    print('There are %d GPU(s) available.' % torch.cuda.device_count())

    print('We will use the GPU:', torch.cuda.get_device_name(0))

# If not...
else:
    print('No GPU available, using the CPU instead.')
    device = torch.device("cpu")
# Out:
# There are 1 GPU(s) available.
# We will use the GPU: Tesla T4

# %%
from transformers import BertTokenizer
from transformers import BertForSequenceClassification
# Load the tokenizer.
tokenizer = BertTokenizer.from_pretrained("asafaya/bert-base-arabic")
# Load the model.

# %%
# Tokenize all of the sentences and map the tokens to thier word IDs.
input_ids = []
attention_masks = []

# For every sentence...
for sent in data['text']:
    # `encode_plus` will:
    #   (1) Tokenize the sentence.
    #   (2) Prepend the `[CLS]` token to the start.
    #   (3) Append the `[SEP]` token to the end.
    #   (4) Map tokens to their IDs.
    #   (5) Pad or truncate the sentence to `max_length`
    #   (6) Create attention masks for [PAD] tokens.
    encoded_dict = tokenizer.encode_plus(
                        sent,                      # Sentence to encode.
                        add_special_tokens = True, # Add '[CLS]' and '[SEP]'
                        max_length = 50,           # Pad & truncate all sentences.
                        pad_to_max_length = True,
                        return_attention_mask = True,   # Construct attn. masks.
                        return_tensors = 'pt',     # Return pytorch tensors.
                   )
    
    # Add the encoded sentence to the list.    
    input_ids.append(encoded_dict['input_ids'])
    
    # And its attention mask (simply differentiates padding from non-padding).
    attention_masks.append(encoded_dict['attention_mask'])

# Convert the lists into tensors.
input_ids = torch.cat(input_ids, dim=0)
attention_masks = torch.cat(attention_masks, dim=0)
labels = torch.tensor(labels)

# Print sentence 0, now as a list of IDs.
print('Original: ', data['text'][0])
print('Token IDs:', input_ids[0])

# %%
from torch.utils.data import TensorDataset, random_split

# Combine the training inputs into a TensorDataset.
dataset = TensorDataset(input_ids, attention_masks, labels)

# Create a 90-10 train-validation split.

# Calculate the number of samples to include in each set.
train_size = int(0.9 * len(dataset))
val_size = len(dataset) - train_size

# Divide the dataset by randomly selecting samples.
train_dataset, val_dataset = random_split(dataset, [train_size, val_size],generator=torch.Generator().manual_seed(87))

print('{:>5,} training samples'.format(train_size))
print('{:>5,} validation samples'.format(val_size))

# %%
from torch.utils.data import DataLoader, RandomSampler, SequentialSampler

# The DataLoader needs to know our batch size for training, so we specify it 
# here. For fine-tuning BERT on a specific task, the authors recommend a batch 
# size of 16 or 32.
batch_size = 32

# Create the DataLoaders for our training and validation sets.
# We'll take training samples in random order. 
train_dataloader = DataLoader(
            train_dataset,  # The training samples.
            sampler = RandomSampler(train_dataset), # Select batches randomly
            batch_size = batch_size # Trains with this batch size.
        )

# For validation the order doesn't matter, so we'll just read them sequentially.
validation_dataloader = DataLoader(
            val_dataset, # The validation samples.
            sampler = SequentialSampler(val_dataset), # Pull out batches sequentially.
            batch_size = batch_size # Evaluate with this batch size.
        )

# %%
from transformers import BertForSequenceClassification, AdamW, BertConfig

# Load BertForSequenceClassification, the pretrained BERT model with a single 
# linear classification layer on top. 
model = BertForSequenceClassification.from_pretrained("asafaya/bert-base-arabic", num_labels = 40)

# Tell pytorch to run this model on the GPU.
_=model.cuda()
# Out:
# Some weights of the model checkpoint at asafaya/bert-base-arabic were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.LayerNorm.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at asafaya/bert-base-arabic and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# Get all of the model's parameters as a list of tuples.
params = list(model.named_parameters())

print('The BERT model has {:} different named parameters.\n'.format(len(params)))

print('==== Embedding Layer ====\n')

for p in params[0:5]:
    print("{:<55} {:>12}".format(p[0], str(tuple(p[1].size()))))

print('\n==== First Transformer ====\n')

for p in params[5:21]:
    print("{:<55} {:>12}".format(p[0], str(tuple(p[1].size()))))

print('\n==== Output Layer ====\n')

for p in params[-4:]:
    print("{:<55} {:>12}".format(p[0], str(tuple(p[1].size()))))
# Out:
# The BERT model has 201 different named parameters.
#
# ==== Embedding Layer ====
#
# bert.embeddings.word_embeddings.weight                  (32000, 768)
# bert.embeddings.position_embeddings.weight                (512, 768)
# bert.embeddings.token_type_embeddings.weight                (2, 768)
# bert.embeddings.LayerNorm.weight                              (768,)
# bert.embeddings.LayerNorm.bias                                (768,)
#
# ==== First Transformer ====
#
# bert.encoder.layer.0.attention.self.query.weight          (768, 768)
# bert.encoder.layer.0.attention.self.query.bias                (768,)
# bert.encoder.layer.0.attention.self.key.weight            (768, 768)
# bert.encoder.layer.0.attention.self.key.bias                  (768,)
# bert.encoder.layer.0.attention.self.value.weight          (768, 768)
# bert.encoder.layer.0.attention.self.value.bias                (768,)
# bert.encoder.layer.0.attention.output.dense.weight        (768, 768)
# bert.encoder.layer.0.attention.output.dense.bias              (768,)
# bert.encoder.layer.0.attention.output.LayerNorm.weight        (768,)
# bert.encoder.layer.0.attention.output.LayerNorm.bias          (768,)
# bert.encoder.layer.0.intermediate.dense.weight           (3072, 768)
# bert.encoder.layer.0.intermediate.dense.bias                 (3072,)
# bert.encoder.layer.0.output.dense.weight                 (768, 3072)
# bert.encoder.layer.0.output.dense.bias                        (768,)
# bert.encoder.layer.0.output.LayerNorm.weight                  (768,)
# bert.encoder.layer.0.output.LayerNorm.bias                    (768,)
#
# ==== Output Layer ====
#
# bert.pooler.dense.weight                                  (768, 768)
# bert.pooler.dense.bias                                        (768,)
# classifier.weight                                          (40, 768)
# classifier.bias                                                (40,)

# %%
optimizer = AdamW(model.parameters(),
                  lr = 5e-5, # args.learning_rate - default is 5e-5, our notebook had 2e-5
                  eps = 1e-8 # args.adam_epsilon  - default is 1e-8.
                )

# %%
from transformers import get_linear_schedule_with_warmup

# Number of training epochs. The BERT authors recommend between 2 and 4. 
# We chose to run for 4, but we'll see later that this may be over-fitting the
# training data.
epochs = 4

# Total number of training steps is [number of batches] x [number of epochs]. 
# (Note that this is not the same as the number of training samples).
total_steps = len(train_dataloader) * epochs

# Create the learning rate scheduler.
scheduler = get_linear_schedule_with_warmup(optimizer, 
                                            num_warmup_steps = 0, # Default value in run_glue.py
                                            num_training_steps = total_steps)

# %%
# Function to calculate the accuracy of our predictions vs labels
def flat_accuracy(preds, labels):
    pred_flat = np.argmax(preds, axis=1).flatten()
    labels_flat = labels.flatten()
    return np.sum(pred_flat == labels_flat) / len(labels_flat)

# %%
import time
import datetime

def format_time(elapsed):
    '''
    Takes a time in seconds and returns a string hh:mm:ss
    '''
    # Round to the nearest second.
    elapsed_rounded = int(round((elapsed)))
    
    # Format as hh:mm:ss
    return str(datetime.timedelta(seconds=elapsed_rounded))

# %%
# import json
# pd.read_json('/content/drive/MyDrive/model/config.json')

# %%
import random
# This training code is based on the `run_glue.py` script here:
# https://github.com/huggingface/transformers/blob/5bfcd0485ece086ebcbed2d008813037968a9e58/examples/run_glue.py#L128

# Set the seed value all over the place to make this reproducible.
seed_val = 42

random.seed(seed_val)
np.random.seed(seed_val)
torch.manual_seed(seed_val)
torch.cuda.manual_seed_all(seed_val)

# We'll store a number of quantities such as training and validation loss, 
# validation accuracy, and timings.
training_stats = []

# Measure the total training time for the whole run.
total_t0 = time.time()

# For each epoch...
for epoch_i in range(0, epochs):
    
    # ========================================
    #               Training
    # ========================================
    
    # Perform one full pass over the training set.

    print("")
    print('======== Epoch {:} / {:} ========'.format(epoch_i + 1, epochs))
    print('Training...')

    # Measure how long the training epoch takes.
    t0 = time.time()

    # Reset the total loss for this epoch.
    total_train_loss = 0

    # Put the model into training mode. Don't be mislead--the call to 
    # `train` just changes the *mode*, it doesn't *perform* the training.
    # `dropout` and `batchnorm` layers behave differently during training
    # vs. test (source: https://stackoverflow.com/questions/51433378/what-does-model-train-do-in-pytorch)
    model.train()

    # For each batch of training data...
    for step, batch in enumerate(train_dataloader):

        # Progress update every 40 batches.
        if step % 40 == 0 and not step == 0:
            # Calculate elapsed time in minutes.
            elapsed = format_time(time.time() - t0)
            
            # Report progress.
            print('  Batch {:>5,}  of  {:>5,}.    Elapsed: {:}.'.format(step, len(train_dataloader), elapsed))

        # Unpack this training batch from our dataloader. 
        #
        # As we unpack the batch, we'll also copy each tensor to the GPU using the 
        # `to` method.
        #
        # `batch` contains three pytorch tensors:
        #   [0]: input ids 
        #   [1]: attention masks
        #   [2]: labels 
        b_input_ids = batch[0].to(device)
        b_input_mask = batch[1].to(device)
        b_labels = batch[2].to(device)

        # Always clear any previously calculated gradients before performing a
        # backward pass. PyTorch doesn't do this automatically because 
        # accumulating the gradients is "convenient while training RNNs". 
        # (source: https://stackoverflow.com/questions/48001598/why-do-we-need-to-call-zero-grad-in-pytorch)
        #model.zero_grad()        

        # Perform a forward pass (evaluate the model on this training batch).
        # The documentation for this `model` function is here: 
        # https://huggingface.co/transformers/v2.2.0/model_doc/bert.html#transformers.BertForSequenceClassification
        # It returns different numbers of parameters depending on what arguments
        # arge given and what flags are set. For our useage here, it returns
        # the loss (because we provided labels) and the "logits"--the model
        # outputs prior to activation.
        loss, logits = model(b_input_ids, 
                             token_type_ids=None, 
                             attention_mask=b_input_mask, 
                             labels=b_labels).values()

        # Accumulate the training loss over all of the batches so that we can
        # calculate the average loss at the end. `loss` is a Tensor containing a
        # single value; the `.item()` function just returns the Python value 
        # from the tensor.

        total_train_loss += loss.item()

        # Perform a backward pass to calculate the gradients.
        loss.backward()

        # Clip the norm of the gradients to 1.0.
        # This is to help prevent the "exploding gradients" problem.
        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)

        # Update parameters and take a step using the computed gradient.
        # The optimizer dictates the "update rule"--how the parameters are
        # modified based on their gradients, the learning rate, etc.
        optimizer.step()

        # Update the learning rate.
        scheduler.step()

    # Calculate the average loss over all of the batches.
    avg_train_loss = total_train_loss / len(train_dataloader)            
    
    # Measure how long this epoch took.
    training_time = format_time(time.time() - t0)

    print("")
    print("  Average training loss: {0:.2f}".format(avg_train_loss))
    print("  Training epcoh took: {:}".format(training_time))
        
    # ========================================
    #               Validation
    # ========================================
    # After the completion of each training epoch, measure our performance on
    # our validation set.

    print("")
    print("Running Validation...")

    t0 = time.time()

    # Put the model in evaluation mode--the dropout layers behave differently
    # during evaluation.
    model.eval()

    # Tracking variables 
    total_eval_accuracy = 0
    total_eval_loss = 0
    nb_eval_steps = 0

    # Evaluate data for one epoch
    for batch in validation_dataloader:
        
        # Unpack this training batch from our dataloader. 
        #
        # As we unpack the batch, we'll also copy each tensor to the GPU using 
        # the `to` method.
        #
        # `batch` contains three pytorch tensors:
        #   [0]: input ids 
        #   [1]: attention masks
        #   [2]: labels 
        b_input_ids = batch[0].to(device)
        b_input_mask = batch[1].to(device)
        b_labels = batch[2].to(device)
        
        # Tell pytorch not to bother with constructing the compute graph during
        # the forward pass, since this is only needed for backprop (training).
        with torch.no_grad():        

            # Forward pass, calculate logit predictions.
            # token_type_ids is the same as the "segment ids", which 
            # differentiates sentence 1 and 2 in 2-sentence tasks.
            # The documentation for this `model` function is here: 
            # https://huggingface.co/transformers/v2.2.0/model_doc/bert.html#transformers.BertForSequenceClassification
            # Get the "logits" output by the model. The "logits" are the output
            # values prior to applying an activation function like the softmax.
            (loss, logits) = model(b_input_ids, 
                                   token_type_ids=None, 
                                   attention_mask=b_input_mask,
                                   labels=b_labels).values()
            
        # Accumulate the validation loss.
        total_eval_loss += loss.item()

        # Move logits and labels to CPU
        logits = logits.detach().cpu().numpy()
        label_ids = b_labels.to('cpu').numpy()

        # Calculate the accuracy for this batch of test sentences, and
        # accumulate it over all batches.
        total_eval_accuracy += flat_accuracy(logits, label_ids)
        

    # Report the final accuracy for this validation run.
    avg_val_accuracy = total_eval_accuracy / len(validation_dataloader)
    print("  Accuracy: {0:.2f}".format(avg_val_accuracy))

    # Calculate the average loss over all of the batches.
    avg_val_loss = total_eval_loss / len(validation_dataloader)
    
    # Measure how long the validation run took.
    validation_time = format_time(time.time() - t0)
    
    print("  Validation Loss: {0:.2f}".format(avg_val_loss))
    print("  Validation took: {:}".format(validation_time))

    # Record all statistics from this epoch.
    training_stats.append(
        {
            'epoch': epoch_i + 1,
            'Training Loss': avg_train_loss,
            'Valid. Loss': avg_val_loss,
            'Valid. Accur.': avg_val_accuracy,
            'Training Time': training_time,
            'Validation Time': validation_time
        }
    )

print("")
print("Training complete!")

print("Total training took {:} (h:mm:ss)".format(format_time(time.time()-total_t0)))
# Out:
# ======== Epoch 1 / 4 ========
# Training...
#   Batch    40  of     57.    Elapsed: 0:00:12.
#
#   Average training loss: 2.76
#   Training epcoh took: 0:00:16
#
# Running Validation...
#   Accuracy: 0.53
#   Validation Loss: 2.10
#   Validation took: 0:00:01
#
# ======== Epoch 2 / 4 ========
# Training...
#   Batch    40  of     57.    Elapsed: 0:00:12.
#
#   Average training loss: 1.51
#   Training epcoh took: 0:00:17
#
# Running Validation...
#   Accuracy: 0.79
#   Validation Loss: 1.25
#   Validation took: 0:00:01
#
# ======== Epoch 3 / 4 ========
# Training...
#   Batch    40  of     57.    Elapsed: 0:00:12.
#
#   Average training loss: 0.79
#   Training epcoh took: 0:00:17
#
# Running Validation...
#   Accuracy: 0.82
#   Validation Loss: 0.93
#   Validation took: 0:00:01
#
# ======== Epoch 4 / 4 ========
# Training...
#   Batch    40  of     57.    Elapsed: 0:00:12.
#
#   Average training loss: 0.49
#   Training epcoh took: 0:00:16
#
# Running Validation...
#   Accuracy: 0.85
#   Validation Loss: 0.80
#   Validation took: 0:00:01
#
# Training complete!
# Total training took 0:01:09 (h:mm:ss)

# %%
# Display floats with two decimal places.
pd.set_option('precision', 2)

# Create a DataFrame from our training statistics.
df_stats = pd.DataFrame(data=training_stats)

# Use the 'epoch' as the row index.
df_stats = df_stats.set_index('epoch')

# A hack to force the column headers to wrap.
#df = df.style.set_table_styles([dict(selector="th",props=[('max-width', '70px')])])

# Display the table.
df_stats
# Out:
#        Training Loss  Valid. Loss  Valid. Accur. Training Time Validation Time
# epoch
# 1               2.76         2.10           0.53       0:00:16         0:00:01
# 2               1.51         1.25           0.79       0:00:17         0:00:01
# 3               0.79         0.93           0.82       0:00:17         0:00:01
# 4               0.49         0.80           0.85       0:00:16         0:00:01

# %%
import matplotlib.pyplot as plt
% matplotlib inline

import seaborn as sns

# Use plot styling from seaborn.
sns.set(style='darkgrid')

# Increase the plot size and font size.
sns.set(font_scale=1.5)
plt.rcParams["figure.figsize"] = (12,6)

# Plot the learning curve.
plt.plot(df_stats['Training Loss'], 'b-o', label="Training")
plt.plot(df_stats['Valid. Loss'], 'g-o', label="Validation")

# Label the plot.
plt.title("Training & Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.xticks([1, 2, 3, 4])

plt.show()

# %%
torch.save(model.state_dict(), '/content/drive/MyDrive/model_4.bin')

# %% [markdown]
# # Modelling

# %%
X_train, X_valid , y_train, y_valid = train_test_split(tokenized_matrix, labels, test_size = 0.10, random_state = 3)

# %%
# def define_model(length, vocab_size,embedding_dim=100,dropout_prob=0.2):
#   # channel 1
#   inputs1 = Input(shape=(length,))
#   embedding1 = Embedding(vocab_size, embedding_dim)(inputs1)
#   conv1 = Conv1D(filters=32, kernel_size=4, activation='relu')(embedding1)
#   BN1 = BatchNormalization()(conv1)
#   drop1 = Dropout(dropout_prob)(BN1)
#   pool1 = MaxPooling1D(pool_size=2)(drop1)
#   flat1 = Flatten()(pool1)
#   # channel 2
#   inputs2 = Input(shape=(length,))
#   embedding2 = Embedding(vocab_size, embedding_dim)(inputs2)
#   conv2 = Conv1D(filters=32, kernel_size=6, activation='relu')(embedding2)
#   BN2 = BatchNormalization()(conv2)
#   drop2 = Dropout(dropout_prob)(BN2)
#   pool2 = MaxPooling1D(pool_size=2)(drop2)
#   flat2 = Flatten()(pool2)
#   # channel 3
#   inputs3 = Input(shape=(length,))
#   embedding3 = Embedding(vocab_size, embedding_dim)(inputs3)
#   conv3 = Conv1D(filters=32, kernel_size=8, activation='relu')(embedding3)
#   BN3 = BatchNormalization()(conv3)
#   drop3 = Dropout(dropout_prob)(BN3)
#   pool3 = MaxPooling1D(pool_size=2)(drop3)
#   flat3 = Flatten()(pool3)
#   # merge
#   merged = concatenate([flat1, flat2, flat3])
#   # interpretation
#   dense1 = Dense(64, activation='relu')(merged)
#   outputs = Dense(40, activation='softmax')(dense1)
#   model = Model(inputs=[inputs1,inputs2,inputs3], outputs=outputs)
#   # compile
#   model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
#   # summarize
#   return model

# %%
# class TransformerBlock(layers.Layer):
#     def __init__(self, embed_dim, num_heads, ff_dim, rate=0.1):
#         super(TransformerBlock, self).__init__()
#         self.att = layers.MultiHeadAttention(num_heads=num_heads, key_dim=embed_dim)
#         self.ffn = keras.Sequential(
#             [layers.Dense(ff_dim, activation="relu"), layers.Dense(embed_dim),]
#         )
#         self.layernorm1 = layers.LayerNormalization(epsilon=1e-6)
#         self.layernorm2 = layers.LayerNormalization(epsilon=1e-6)
#         self.dropout1 = layers.Dropout(rate)
#         self.dropout2 = layers.Dropout(rate)

#     def call(self, inputs, training):
#         attn_output = self.att(inputs, inputs)
#         attn_output = self.dropout1(attn_output, training=training)
#         out1 = self.layernorm1(inputs + attn_output)
#         ffn_output = self.ffn(out1)
#         ffn_output = self.dropout2(ffn_output, training=training)
#         return self.layernorm2(out1 + ffn_output)

# class TokenAndPositionEmbedding(layers.Layer):
#     def __init__(self, maxlen, vocab_size, embed_dim):
#         super(TokenAndPositionEmbedding, self).__init__()
#         self.token_emb = layers.Embedding(input_dim=vocab_size, output_dim=embed_dim)
#         self.pos_emb = layers.Embedding(input_dim=maxlen, output_dim=embed_dim)

#     def call(self, x):
#         maxlen = tf.shape(x)[-1]
#         positions = tf.range(start=0, limit=maxlen, delta=1)
#         positions = self.pos_emb(positions)
#         x = self.token_emb(x)
#         return x + positions

# %%
def define_model(length, vocab_size,embed_dim=100,num_heads=3,ff_dim=64,dropout_prob=0.1):
  inputs = layers.Input(shape=(length,))
  embedding_layer = Embeddinginput_dim =len(my_vocab), output_dim=embed_dim,weights=[my_vocab.embedding_matrix], input_length=length,trainable=False) #TokenAndPositionEmbedding(length, vocab_size, embed_dim)
  x = embedding_layer(inputs)
  transformer_block = TransformerBlock(embed_dim, num_heads, ff_dim)
  x = transformer_block(x)
  x = layers.GlobalAveragePooling1D()(x)
  x = layers.Dropout(dropout_prob)(x)
  x = layers.Dense(128, activation="relu")(x)
  x = layers.Dropout(dropout_prob)(x)
  outputs = layers.Dense(40, activation="softmax")(x)

  model = keras.Model(inputs=inputs, outputs=outputs)
  model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

  return model

# %%
model = define_model(50,100)
model.summary()

# %%
# callbacks = [tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=2, min_delta=0.0001, min_lr=0.0001)]
# callbacks += [tf.keras.callbacks.ModelCheckpoint('/content/drive/MyDrive/dataset/final_model.h5', monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')]
# callbacks += [
#     tf.keras.callbacks.EarlyStopping(
#         monitor='val_accuracy',
#         patience=5)]

# %%
model.fit(X_train,y_train,validation_data= (X_valid, y_valid),epochs=100, batch_size=16)

# %% [markdown]
# # Testing

# %%
test_data = pd.read_csv('/content/drive/MyDrive/dataset/test.csv',index_col=0)
test_data
# Out:
#                                                     text
# index
# 0                               كان إعداد الإصابات ف مصر
# 1                اعداد المصابين الان في مصر بفيرس كورونا
# 2                                                اسرائيل
# 3                     هل تم التوصل لمصل للوقاية من كرونا
# 4                                      الحالات في امريكا
# ...                                                  ...
# 193                                                نميسه
# 194                               انتي مرتبطة يا نميسة ؟
# 195                           اعداد المصابين  فى بورسعيد
# 196    انا جايبه عفش من دمياط و دي منطقة وباء ممكن اع...
# 197                                        اعراض الكورنا
#
# [198 rows x 1 columns]

# %%
model = BertForSequenceClassification.from_pretrained("asafaya/bert-base-arabic", num_labels = 40)
#checkpoint = torch.load('/content/drive/MyDrive/model/pytorch_model.bin')
if torch.device("cpu") != device:
  checkpoint = torch.load('/content/drive/MyDrive/model/pytorch_model.bin')
else:
  checkpoint = torch.load('/content/drive/MyDrive/model/pytorch_model.bin', map_location='cpu')
model.load_state_dict(checkpoint)
model = model.to(device)
# Out:
# Some weights of the model checkpoint at asafaya/bert-base-arabic were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at asafaya/bert-base-arabic and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
! transformers-cli repo create machathonmodel

# %%
# !sudo apt-get install git-lfs
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# git-lfs is already the newest version (2.3.4-1).
# 0 upgraded, 0 newly installed, 0 to remove and 39 not upgraded.

# %%
# !git config --global user.email "moaazzaki1999@gmail.com"
# !git config --global user.name "MoaazZaki"

# %%
model.push_to_hub("machathonmodel")

# %%
# Create sentence and label lists
sentences = test_data.text.values
#del labels
# Tokenize all of the sentences and map the tokens to thier word IDs.
input_ids = []
attention_masks = []

# For every sentence...
for sent in sentences:
    # `encode_plus` will:
    #   (1) Tokenize the sentence.
    #   (2) Prepend the `[CLS]` token to the start.
    #   (3) Append the `[SEP]` token to the end.
    #   (4) Map tokens to their IDs.
    #   (5) Pad or truncate the sentence to `max_length`
    #   (6) Create attention masks for [PAD] tokens.
    encoded_dict = tokenizer.encode_plus(
                        sent,                      # Sentence to encode.
                        add_special_tokens = True, # Add '[CLS]' and '[SEP]'
                        max_length = 50,           # Pad & truncate all sentences.
                        pad_to_max_length = True,
                        return_attention_mask = True,   # Construct attn. masks.
                        return_tensors = 'pt',     # Return pytorch tensors.
                   )
    
    # Add the encoded sentence to the list.    
    input_ids.append(encoded_dict['input_ids'])
    
    # And its attention mask (simply differentiates padding from non-padding).
    attention_masks.append(encoded_dict['attention_mask'])

# Convert the lists into tensors.
input_ids = torch.cat(input_ids, dim=0)
attention_masks = torch.cat(attention_masks, dim=0)
#labels = torch.tensor(labels)

# Set the batch size.  
batch_size = 1  

# Create the DataLoader.
prediction_data = TensorDataset(input_ids, attention_masks)
prediction_sampler = SequentialSampler(prediction_data)
prediction_dataloader = DataLoader(prediction_data, sampler=prediction_sampler, batch_size=batch_size)
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2110: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,

# %%
model.eval()

# Tracking variables 
predictions , true_labels = [], []

# Predict 
for batch in prediction_dataloader:
  # Add batch to GPU
  batch = tuple(t.to(device) for t in batch)
  
  # Unpack the inputs from our dataloader
  b_input_ids, b_input_mask = batch
  
  # Telling the model not to compute or store gradients, saving memory and 
  # speeding up prediction
  with torch.no_grad():
      # Forward pass, calculate logit predictions
      outputs = model(b_input_ids, token_type_ids=None, 
                      attention_mask=b_input_mask)

  logits = outputs[0]

  # Move logits and labels to CPU
  logits = logits.detach().cpu().numpy()
  #label_ids = b_labels.to('cpu').numpy()
  
  # Store predictions and true labels
  predictions.append(np.argmax(logits, axis=1)[0])
  #true_labels.append(label_ids)

print('    DONE.')
# Out:
#     DONE.

# %%
len(predictions)
# Out:
# 198

# %%
pd.DataFrame(le.inverse_transform(predictions)).reset_index().rename(columns={0:'intent'}).to_csv('model9.csv', index=False)

# %%
#.rename(columns={0:'intent'}

# %%
# def getResults(data):
#   test = BERTDataset(text=test_data['text'].to_list(),target=np.random.randint(0,39),model_name=model_name,max_len=max_len,label_map=label_map)
#   y_pred =trainer.predict(test_dataset=test)
#   return np.argmax(model.predict(x_test),axis=1)

# %%
# trainer.save_model('/content/drive/MyDrive/model')

# %% [markdown]
# # HELPERS

# %% [markdown]
# ## Helper Preprocessing

# %%
def clean_text(string):
  """
  Sources 
  ----------
  https://stackabuse.com/using-regex-for-text-manipulation-in-python/
  https://lionbridge.ai/articles/using-natural-language-processing-for-spam-detection-in-emails/
  
  Description
  -----------
  clean text by handling unneeded words

  Parameters
  ----------
  string : str
      string to be processed

  Returns
  -------
  str
      cleaned string
  """
  string = str(string) if type(string) != type('aa') else string
  string = string.lower()
  string = re.sub(r"http\S+", "", string)
  string = re.sub(r"\W", " ", string, flags=re.I)
  string = re.sub(r"[^A-Za-z0-9]", " ", string)
  string = re.sub(r"\'s", " is ", string)
  string = re.sub(r"\'ve", " have ", string)
  string = re.sub(r"can't", "cannot ", string)
  string = re.sub(r"n't", " not ", string)
  string = re.sub(r"I'm", "I am", string)
  string = re.sub(r"\'re", " are ", string)
  string = re.sub(r"\'d", " would ", string)
  string = re.sub(r"\'ll", " will ", string)
  string = re.sub(r"e-mail", "email", string)
  string = re.sub(r" usa ", " america ", string)
  string = re.sub(r" uk ", " england ", string)
  string = re.sub(r"\s+"," ", string, flags = re.I)
  string = string[7:] if re.search(r"^subject", string) else string
  string = re.sub(r"^\s+", "", string)
  string = string[7:] if re.search(r"^re", string) else string
  string = re.sub(r"^\s+", "", string)
  string = re.sub(r"\s+$", "", string)
  string = re.sub(r"\s+[a-zA-Z]\s+", " ", string)

  return string

# %%
def tokenizer(text):
  """
  Sources 
  ----------
  
  Description
  -----------
  Converts text to set of encoded words

  Parameters
  ----------
  text : pd.Series
      data to be processed

  Returns
  -------
  pd.Series
      processed data
  """

  tk = Tokenizer(num_words=TOKENIZER_WORD_NUM)
  tk.fit_on_texts(text)
  return pd.Series(tk.texts_to_sequences(text))

# %%
def preprocess_text(text,tokenizer=word_tokenize,stops_remove=True,stemmer = SnowballStemmer('english'),stop_words=stopwords.words('english')):
  """
  Sources 
  ----------
  
  Description
  -----------
  Perform the whole preprocessing pipeline for a given text

  Parameters
  ----------
  text : str
      text to be processed

  tokenizer: function (optional)
      used tokenizer

  stemmer: object (optional)
      used stemmer

  stops_remove: list (optional)
      stop words to be removed

  

  Returns
  -------
  str
      processed string
  """
  
  # (1) Cleaning text
  text = clean_text(text)

  # (2) Tokenizing
  text = tokenizer(text)
  
  # (3) Removing stopwords
  text = [word for word in text if word not in stop_words]

  # (4) Stemming
  text = [stemmer.stem(word) for word in text]

  return text

# %%
def preprocess_df(df,X,y,tokenizer=word_tokenize,stops_remove=True,stemmer = SnowballStemmer('english'),stop_words=stopwords.words('english')):
  """
  Sources 
  ----------
  
  Description
  -----------
  Perform the whole preprocessing pipeline for a given dataframe

  Parameters
  ----------
  text : pd.DataFrame
      dataframe to be processed

  tokenizer: function (optional)
      used tokenizer

  stemmer: object (optional)
      used stemmer

  stops_remove: list (optional)
      stop words to be removed

  

  Returns
  -------
  pd.DataFrame
      processed dataframe
  """
  df_unique = df.drop_duplicates()
  df_ = pd.DataFrame(df_unique[X].apply(lambda x: preprocess_text(x,tokenizer=tokenizer,stops_remove=stops_remove,stemmer=stemmer,stop_words=stop_words)))  
  df_[y] = df_unique[y]
  return df_

# %%
def prepare_data(df,X,length_col,vocab):
  # (1) Encoding words
  df[X] = df[X].apply(lambda sentence: [vocab[word] for word in sentence])

  # (2) Padding/Truncating rows
  length_stats = df[length_col].describe()
  common_length = length_stats.loc['75%']
  max_length = length_stats.loc['max']
  picked_length = int( max_length if common_length / max_length >= 0.5 else common_length)

  df[X] = df[X].apply(lambda sentence: sentence + [0]*(picked_length-len(sentence)) if len(sentence) < common_length else sentence[:picked_length])

# %% [markdown]
# # Helper Feature Extraction

# %%
class Vocabulary:
  """
  Description
  -----------
  - Keeps the words in dataset with count
  - Gives a token for each word
  """

  def __init__(self,max_vocab_size=-1):
    """  
    Description
    -----------
      Initialize vocabulary 

    Parameters
    ----------
    max_vocab_size : int
      maximum vocabulary size
    """
    # Members
    self.word_to_index = dict()
    self.index_to_word = dict()
    self.word_count = pd.Series(dtype=np.int32)
    self.unique_word_count = pd.Series(dtype=np.int32)
    self.prev_sentence_index = -1
    self.vocab_size = 0
    
    self.max_vocab_size = max_vocab_size

    self.word_to_index[' '] = self.vocab_size
    self.index_to_word[self.vocab_size] = '<empty>'
    self.vocab_size += 1
    self.word_count.loc['<empty>'] = GAMMA

    self.word_to_index['<unkown>'] = self.vocab_size
    self.index_to_word[self.vocab_size] = '<unkown>'
    self.vocab_size += 1
    self.word_count.loc['<unkown>'] = GAMMA

    self.tf_dict = {}

  def __len__(self):
    """
    Description
    -----------
      Get the size of vocabulary
    """
    return self.vocab_size

  def __getitem__(self,key):
    """
    Description
    -----------
      Get the size of vocabulary

    Parameters
    ----------
    key : int/str
      Index/word to get its corresponding word/index

    Returns
    -------
    int/str
      Query
    """

    # If key is string
    if type(key) == type('ss'):
      query = 1
      try: 
        query = self.word_to_index[key]
      except:
        pass
      return query
    # If key is integer
    elif type(key) == type(50):
      query = 0
      try:
        query = self.index_to_word[key]
      except:
        raise KeyError('Index out of range')
      return query
    # If key is an unknown type
    else:
      raise KeyError("Invalid key type, key must be string or integer")


  def add_word(self,word,sentence_index=0,sentence_len=1,calculate_tf = False):
    """
    Description
    -----------
      Add word to the vocabulary

    Parameters
    ----------
    word : str
      Word to be added

    Returns
    -------
    bool
      The state of adding the word (success/fail)
    """   
    
    try:
      self.word_count.loc[word] += 1
      if self.prev_sentence_index != sentence_index:
        self.unique_word_count[word] += 1
        self.prev_sentence_index = sentence_index
      if calculate_tf:
        try:
          self.tf_dict[word][sentence_index] += 1/(sentence_len+GAMMA)
        except:
          self.tf_dict[word][sentence_index] = 1/(sentence_len+GAMMA)
    except:
      # If the vocab reached max size
      if self.vocab_size == self.max_vocab_size:
        return False
      # Adding new word
      self.word_count.loc[word] = 1
      self.unique_word_count.loc[word] = 1
      self.prev_sentence_index = sentence_index
      self.word_to_index[word] = self.vocab_size
      self.index_to_word[self.vocab_size] = word
      self.vocab_size += 1
      if calculate_tf:
        self.tf_dict[word] = {sentence_index:1/(sentence_len+GAMMA)}
    
    return True

  def create_vocab(self,df,X='Body',calculate_tfidf = False):
    for index,sentence in enumerate(df[X]):
      for word in sentence:
        my_vocab.add_word(word,index,len(sentence),calculate_tfidf)
    
    if calculate_tfidf:
      self.create_tfidf_matrix(df)

  def get_vocab_words(self):
    return self.index_to_word.values()

  def create_tfidf_matrix(self,df,X='Body'):
    self.tfidf_matrix = np.empty([len(df),self.vocab_size],dtype=np.float64)

    for word,dic in self.tf_dict.items():
      for index,word_tf in dic.items():
        idf = np.log(len(df) / self.unique_word_count.loc[word])
        self.tfidf_matrix[index,self.word_to_index[word]] = word_tf * idf

  
  def add_vectorizer(self,vectorizer):
    """
    Description
    -----------
      Add vectorized object

    Parameters
    ----------
    word : str
      Word to be added

    Returns
    -------
    bool
      The state of adding the word (success/fail)
    """
    self.vectorizer = vectorizer

  def word_to_vector(self,word):
    vector = np.zeros(EMBEDDING_DIM)
    try:
      vector = self.vectorizer[word]
    except:
      pass
    return vector

  def create_embedding_matrix(self):
    self.embedding_matrix = np.empty([self.vocab_size,EMBEDDING_DIM],dtype=np.float64)
    for index,word in self.index_to_word.items():
      self.embedding_matrix[index] = self.word_to_vector(word)

# %% [markdown]
# # Other Data

# %%
# Read, then decode for py2 compat.
def extract_data(path, thresh = 70, on_shatrs = False):
  global vocab
  
  text = ""
  
  X = []
  y = []
    
  t = open(path, 'r').read()
  #t = araby.strip_tashkeel(t)
  # remove some exteranous chars 
  execluded = '!()*-ـ.:=o[]«»;؛,،~?؟\u200f\ufeffـ'
  out = ""
  
  for char in t:
    #if char not in execluded:
    out += char
      
  text += out
  baits = out.split('\n')
  for line in baits:
    if len(line) <= 1:
      continue
    label, bait = line.split(' ', 1)
    label = int(label)

    bait  = bait.strip()
    if on_shatrs:
      shatrs = bait.split('#')
      for shatr in shatrs:
        X.append(shatr.strip())
        y.append(label)
    else:
      X.append(bait.strip())
      y.append(label)
  
  #create the vocab 
  vocab = sorted(set(' '.join(X)))  
  
  #shuffle the data 
  X, y = shuffle(X, y)
  return X, y

# %%
from sklearn.utils import shuffle

# %%
X, y = extract_data("final_baits/test.txt", on_shatrs=False)

# %%
long_data = pd.DataFrame(X).rename(columns={0:'data'})
long_data['labels'] = y
long_data
# Out:
#                                                    data  labels
# 0     بِكُلِّ تَقديسَةٍ يُرَدِّدُها # فيكَ النَصاري ...       4
# 1         تعالَت ذاتُ مَولايَ # عَن الإِدراكِ بِاللَحظِ      12
# 2     بِوادي لَكَ بِالشَوق الَّذي # في فُؤادي لا تدَ...       7
# 3     ومن ألفناه كان الموت فرّقنا # لا يمنع الموت جي...       8
# 4     واسأل الرحمن لي في حاجتي # التي في النفس منها ...       7
# ...                                                 ...     ...
# 8311  دِيَماً في كُلِّ يَومٍ وَوَبلاً # وَاِغتِباقاً...       5
# 8312  وَلقدْ أَنْذَرْتُهُ فَرَأَيْتُهُ # جَاهِلِيَّا...       9
# 8313   في كفّه نبعةٌ مُوَتَّرة # يهزج ابياضًها ويهتضِبُ       4
# 8314  كَأَنَّهُم لِلعُيون تَبصرة # كَأَنَّهُم في الق...       4
# 8315  وَلَئِن طَرِبتُ وَقَد عَرَتني وَعكَةٌ # فَاللَ...       1
#
# [8316 rows x 2 columns]

# %%
ver_long_data = pd.concat([data,long_data],ignore_index=True)
ver_long_data = ver_long_data.drop(labels=["labels_text"], axis=1)
ver_long_data = ver_long_data.drop_duplicates()
ver_long_data = ver_long_data.reset_index().drop(labels=["index"], axis=1)

# %%
ver_long_data
# Out:
#          labels                                               data
# 0             8  أَنا الفقير وباللَه العظيم غني # لئن فقدتك في ...
# 1            10  وَلوعاً بِيُمنَى نَمْنَمَتْها حَدِيقَةٌ # نَزْ...
# 2            11  فيا منْ لم أزلْ أحظى لديه # بفضلٍ جامعٍ بابَ ا...
# 3             9  وَسَلامٌ عَلَى ضَرِيحِكَ مَا أَهْ # دَتْ شَذَا...
# 4             8  أمِنْتُ فقري لما قُلتُ عن ثِقَةٍ # أنْ لا جواد...
# ...         ...                                                ...
# 1471171       0  أَثْقَلَنِي بِالْبِرِّ حَتَّى لَقَدْ # أَعْجِز...
# 1471172       8  إلا لحالَيْن فَقْدِ العقلِ والدينِ # لو رام ذل...
# 1471173       7  حارَبوا الجَهلَ وَكانوا قَبلَنا # في دُجى عَمي...
# 1471174       9  فَقَطَفْتُ الشَّقِيقَ منْ وجْهِهِ # وَاغْتَبَق...
# 1471175      13  فَذاكَ جذرُ المَالِ بالنُّقصان # وَذاكَ جَذرُ ...
#
# [1471176 rows x 2 columns]
